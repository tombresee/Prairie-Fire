# %% [markdown]
# d-sandbox
#
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning" style="width: 600px; height: 163px">
# </div>

# %% [markdown]
# # Lab: Grid Search with MLflow
#
# ## ![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) In this lab you:<br>
#  - Import the housing data
#  - Perform grid search using scikit-learn
#  - Log the best model on MLflow
#  - Load the saved model

# %% [markdown]
# ## ![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) Classroom-Setup & Classroom-Cleanup<br>
#
# For each lesson to execute correctly, please make sure to run the **`Classroom-Setup`** cell at the start of each lesson (see the next cell) and the **`Classroom-Cleanup`** cell at the end of each lesson.

# %%
# %run "../Includes/Classroom-Setup"

# %%
#######################################################################
#                                                                     #
#    This installs MLflow for you only on Databricks Runtime          #
#    NOTE: this code does not work with ML runtime (see below)        #
#                                                                     #
#######################################################################


dbutils.library.installPyPI("mlflow", "1.0.0")
dbutils.library.restartPython()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">PyPI package mlflow has been installed already. The previously-installed package is `mlflow==1.0.0`. To resolve this issue detach and re-attach the notebook to create a new environment or rename the package.
# </div>

# %% [markdown]
# ## Data Import
#
# Load in same Airbnb data and create train/test split.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

df = pd.read_csv("/dbfs/mnt/training/airbnb/sf-listings/airbnb-cleaned-mlflow.csv")
X_train, X_test, y_train, y_test = train_test_split(df.drop(["price"], axis=1), df[["price"]].values.ravel(), random_state=42)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Perform Grid Search using scikit-learn
#
# We want to know which combination of hyperparameter values is the most effective. Fill in the code below to perform <a href="https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html#sklearn.model_selection.GridSearchCV" target="_blank"> grid search using `sklearn`</a> over the 2 hyperparameters we looked at in the 02 notebook, `n_estimators` and `max_depth`.

# %%
# ANSWER
import mlflow.sklearn
from sklearn.ensemble import RandomForestRegressor
# ------------------------------------------------
from sklearn.model_selection import GridSearchCV

# dictionary containing hyperparameter names and list of values we want to try
parameters = {'n_estimators':[100,1000], 
              'max_depth':[10,15]}

rf = RandomForestRegressor()

grid_rf_model = GridSearchCV(rf, parameters, cv=3)

grid_rf_model.fit(X_train, y_train)

best_rf = grid_rf_model.best_estimator_

for p in parameters:
  print("Best '{}': {}".format(p, best_rf.get_params()[p]))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Best &#39;n_estimators&#39;: 1000
# Best &#39;max_depth&#39;: 15
# </div>

# %%
# what i tested with: 

for key,value in parameters.items():
  print(key, " ::  ", value)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">n_estimators  ::   [100, 1000]
# max_depth  ::   [10, 15]
# </div>

# %% [markdown]
# ## Log Best Model on MLflow
#
# Log the best model as `grid-random-forest-model`, its parameters, and its MSE metric under a run with name `RF-Grid-Search` in our new MLflow experiment.

# %%
# ANSWER

from sklearn.metrics import mean_squared_error


with mlflow.start_run(run_name="RF-Grid-Search") as run:
  
  
  # Create predictions of X_test using best model
  predictions = best_rf.predict(X_test)
  # will use this in a bit 
  
  
  # Log model
  mlflow.sklearn.log_model(best_rf, "grid-random-forest-model")
  
  
  # Log params
  model_params = best_rf.get_params()
  
  
  # go thru each of the parameters and log them...
  [mlflow.log_param(p, model_params[p]) for p in parameters]
  
  
  # Create and log MSE metrics using predictions of X_test and its actual value y_test
  mse = mean_squared_error(y_test, predictions)
  mlflow.log_metric("mse", mse)
  
  
  runID = run.info.run_uuid
  artifactURI = mlflow.get_artifact_uri()
  print("Inside MLflow Run with id {} and artifact URI {}".format(runID, artifactURI))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Inside MLflow Run with id c2e07b090d4b417c86eb8a8704e118ea and artifact URI dbfs:/databricks/mlflow/2056266854504964/c2e07b090d4b417c86eb8a8704e118ea/artifacts
# </div>

# %%
# I want the actual model parameters...

for key,value in model_params.items():
  print(key,  "        " , value)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">bootstrap          True
# criterion          mse
# max_depth          15
# max_features          auto
# max_leaf_nodes          None
# min_impurity_decrease          0.0
# min_impurity_split          None
# min_samples_leaf          1
# min_samples_split          2
# min_weight_fraction_leaf          0.0
# n_estimators          100
# n_jobs          None
# oob_score          False
# random_state          None
# verbose          0
# warm_start          False
# </div>

# %%
print(predictions)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[141.74950029 129.44849162 164.19658483 ... 169.21399623 126.68309441
#  130.04229401]
# </div>

# %% [markdown]
# Check on the MLflow UI that the run `RF-Grid-Search` is logged has the best parameter values found by grid search.

# %% [markdown]
# * https://docs.databricks.com/applications/mlflow/quick-start.html

# %% [markdown]
# -sandbox
# ## Load the Saved Model
#
# Load the trained and tuned model we just saved. Check that the hyperparameters of this model matches that of the best model we found earlier.
#
# <img alt="Hint" title="Hint" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.3em" src="https://files.training.databricks.com/static/images/icon-light-bulb.svg"/>&nbsp;**Hint:** Use the `artifactURI` variable declared above.

# %%
# ANSWER
model = mlflow.sklearn.load_model(artifactURI + "/grid-random-forest-model/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Time permitting, continue to grid search over a wider number of parameters and automatically save the best performing parameters back to `mlflow`.

# %% [markdown]
# Time permitting, use the `MlflowClient` to interact programatically with your run.

# %% [markdown]
# ### Examining the actual model object:

# %%
dir(model)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[14]: [&#39;__abstractmethods__&#39;,
#  &#39;__class__&#39;,
#  &#39;__delattr__&#39;,
#  &#39;__dict__&#39;,
#  &#39;__dir__&#39;,
#  &#39;__doc__&#39;,
#  &#39;__eq__&#39;,
#  &#39;__format__&#39;,
#  &#39;__ge__&#39;,
#  &#39;__getattribute__&#39;,
#  &#39;__getitem__&#39;,
#  &#39;__getstate__&#39;,
#  &#39;__gt__&#39;,
#  &#39;__hash__&#39;,
#  &#39;__init__&#39;,
#  &#39;__init_subclass__&#39;,
#  &#39;__iter__&#39;,
#  &#39;__le__&#39;,
#  &#39;__len__&#39;,
#  &#39;__lt__&#39;,
#  &#39;__module__&#39;,
#  &#39;__ne__&#39;,
#  &#39;__new__&#39;,
#  &#39;__reduce__&#39;,
#  &#39;__reduce_ex__&#39;,
#  &#39;__repr__&#39;,
#  &#39;__setattr__&#39;,
#  &#39;__setstate__&#39;,
#  &#39;__sizeof__&#39;,
#  &#39;__str__&#39;,
#  &#39;__subclasshook__&#39;,
#  &#39;__weakref__&#39;,
#  &#39;_abc_impl&#39;,
#  &#39;_estimator_type&#39;,
#  &#39;_get_param_names&#39;,
#  &#39;_make_estimator&#39;,
#  &#39;_set_oob_score&#39;,
#  &#39;_validate_X_predict&#39;,
#  &#39;_validate_estimator&#39;,
#  &#39;_validate_y_class_weight&#39;,
#  &#39;apply&#39;,
#  &#39;base_estimator&#39;,
#  &#39;base_estimator_&#39;,
#  &#39;bootstrap&#39;,
#  &#39;class_weight&#39;,
#  &#39;criterion&#39;,
#  &#39;decision_path&#39;,
#  &#39;estimator_params&#39;,
#  &#39;estimators_&#39;,
#  &#39;feature_importances_&#39;,
#  &#39;fit&#39;,
#  &#39;get_params&#39;,
#  &#39;max_depth&#39;,
#  &#39;max_features&#39;,
#  &#39;max_leaf_nodes&#39;,
#  &#39;min_impurity_decrease&#39;,
#  &#39;min_impurity_split&#39;,
#  &#39;min_samples_leaf&#39;,
#  &#39;min_samples_split&#39;,
#  &#39;min_weight_fraction_leaf&#39;,
#  &#39;n_estimators&#39;,
#  &#39;n_features_&#39;,
#  &#39;n_jobs&#39;,
#  &#39;n_outputs_&#39;,
#  &#39;oob_score&#39;,
#  &#39;predict&#39;,
#  &#39;random_state&#39;,
#  &#39;score&#39;,
#  &#39;set_params&#39;,
#  &#39;verbose&#39;,
#  &#39;warm_start&#39;]</div>

# %%
"""
 'apply',
 'base_estimator',
 'base_estimator_',
 'bootstrap',
 'class_weight',
 'criterion',
 'decision_path',
 'estimator_params',
 'estimators_',
 'feature_importances_',
 'fit',
 'get_params',
 'max_depth',
 'max_features',
 'max_leaf_nodes',
 'min_impurity_decrease',
 'min_impurity_split',
 'min_samples_leaf',
 'min_samples_split',
 'min_weight_fraction_leaf',
 'n_estimators',
 'n_features_',
 'n_jobs',
 'n_outputs_',
 'oob_score',
 'predict',
 'random_state',
 'score',
 'set_params',
 'verbose',
 'warm_start']
 """
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[17]: &#34;\n &#39;apply&#39;,\n &#39;base_estimator&#39;,\n &#39;base_estimator_&#39;,\n &#39;bootstrap&#39;,\n &#39;class_weight&#39;,\n &#39;criterion&#39;,\n &#39;decision_path&#39;,\n &#39;estimator_params&#39;,\n &#39;estimators_&#39;,\n &#39;feature_importances_&#39;,\n &#39;fit&#39;,\n &#39;get_params&#39;,\n &#39;max_depth&#39;,\n &#39;max_features&#39;,\n &#39;max_leaf_nodes&#39;,\n &#39;min_impurity_decrease&#39;,\n &#39;min_impurity_split&#39;,\n &#39;min_samples_leaf&#39;,\n &#39;min_samples_split&#39;,\n &#39;min_weight_fraction_leaf&#39;,\n &#39;n_estimators&#39;,\n &#39;n_features_&#39;,\n &#39;n_jobs&#39;,\n &#39;n_outputs_&#39;,\n &#39;oob_score&#39;,\n &#39;predict&#39;,\n &#39;random_state&#39;,\n &#39;score&#39;,\n &#39;set_params&#39;,\n &#39;verbose&#39;,\n &#39;warm_start&#39;]\n &#34;</div>

# %%
model.get_params
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[18]: &lt;bound method BaseEstimator.get_params of RandomForestRegressor(bootstrap=True, criterion=&#39;mse&#39;, max_depth=15,
#            max_features=&#39;auto&#39;, max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)&gt;</div>

# %%
model.max_depth
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[19]: 15</div>

# %%
model.n_features_
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[20]: 21</div>

# %%
model.score
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[21]: &lt;bound method RegressorMixin.score of RandomForestRegressor(bootstrap=True, criterion=&#39;mse&#39;, max_depth=15,
#            max_features=&#39;auto&#39;, max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)&gt;</div>

# %%
model.verbose
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[24]: 0</div>

# %% [markdown]
# ### Run Object Examination:

# %%
dir(run)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[25]: [&#39;__class__&#39;,
#  &#39;__delattr__&#39;,
#  &#39;__dict__&#39;,
#  &#39;__dir__&#39;,
#  &#39;__doc__&#39;,
#  &#39;__enter__&#39;,
#  &#39;__eq__&#39;,
#  &#39;__exit__&#39;,
#  &#39;__format__&#39;,
#  &#39;__ge__&#39;,
#  &#39;__getattribute__&#39;,
#  &#39;__gt__&#39;,
#  &#39;__hash__&#39;,
#  &#39;__init__&#39;,
#  &#39;__init_subclass__&#39;,
#  &#39;__iter__&#39;,
#  &#39;__le__&#39;,
#  &#39;__lt__&#39;,
#  &#39;__module__&#39;,
#  &#39;__ne__&#39;,
#  &#39;__new__&#39;,
#  &#39;__reduce__&#39;,
#  &#39;__reduce_ex__&#39;,
#  &#39;__repr__&#39;,
#  &#39;__setattr__&#39;,
#  &#39;__sizeof__&#39;,
#  &#39;__str__&#39;,
#  &#39;__subclasshook__&#39;,
#  &#39;__weakref__&#39;,
#  &#39;_data&#39;,
#  &#39;_info&#39;,
#  &#39;_properties&#39;,
#  &#39;data&#39;,
#  &#39;from_dictionary&#39;,
#  &#39;from_proto&#39;,
#  &#39;info&#39;,
#  &#39;to_dictionary&#39;,
#  &#39;to_proto&#39;]</div>

# %%
"""
 'data',
 'from_dictionary',
 'from_proto',
 'info',
 'to_dictionary',
 'to_proto']
"""
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[26]: &#34;\n &#39;data&#39;,\n &#39;from_dictionary&#39;,\n &#39;from_proto&#39;,\n &#39;info&#39;,\n &#39;to_dictionary&#39;,\n &#39;to_proto&#39;]\n&#34;</div>

# %%
for key,value in run.info:
  print(key, " . . . . . . . ", value)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">artifact_uri  . . . . . . .  dbfs:/databricks/mlflow/2056266854504964/c2e07b090d4b417c86eb8a8704e118ea/artifacts
# end_time  . . . . . . .  None
# experiment_id  . . . . . . .  2056266854504964
# lifecycle_stage  . . . . . . .  active
# run_id  . . . . . . .  c2e07b090d4b417c86eb8a8704e118ea
# run_uuid  . . . . . . .  c2e07b090d4b417c86eb8a8704e118ea
# start_time  . . . . . . .  1586281792256
# status  . . . . . . .  RUNNING
# user_id  . . . . . . .
# </div>

# %% [markdown]
# ### Reading Head Files View:

# %%
#  /Users/tbresee@mail.smu.edu/ACADEMY_TRAINING/MLflow-1.2.0-SPNC/Python/Solutions/Labs/02-Lab
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#  	Artifact Location:    dbfs:/databricks/mlflow/2056266854504964
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %fs ls dbfs:/databricks/mlflow/2056266854504964
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/databricks/mlflow/2056266854504964/c2e07b090d4b417c86eb8a8704e118ea/</td><td>c2e07b090d4b417c86eb8a8704e118ea/</td><td>0</td></tr></tbody></table></div>

# %%
# %fs ls dbfs:/databricks/mlflow/2056266854504964/c2e07b090d4b417c86eb8a8704e118ea/artifacts/grid-random-forest-model/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/databricks/mlflow/2056266854504964/c2e07b090d4b417c86eb8a8704e118ea/artifacts/grid-random-forest-model/MLmodel</td><td>MLmodel</td><td>362</td></tr><tr><td>dbfs:/databricks/mlflow/2056266854504964/c2e07b090d4b417c86eb8a8704e118ea/artifacts/grid-random-forest-model/conda.yaml</td><td>conda.yaml</td><td>130</td></tr><tr><td>dbfs:/databricks/mlflow/2056266854504964/c2e07b090d4b417c86eb8a8704e118ea/artifacts/grid-random-forest-model/model.pkl</td><td>model.pkl</td><td>15123079</td></tr></tbody></table></div>

# %%
# %fs head dbfs:/databricks/mlflow/2056266854504964/c2e07b090d4b417c86eb8a8704e118ea/artifacts/grid-random-forest-model/conda.yaml
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">channels:
# - defaults
# dependencies:
# - python=3.7.3
# - scikit-learn=0.20.3
# - pip:
#   - mlflow
#   - cloudpickle==1.3.0
# name: mlflow-env
#
# </div>

# %%
# %fs head dbfs:/databricks/mlflow/2056266854504964/c2e07b090d4b417c86eb8a8704e118ea/artifacts/grid-random-forest-model/MLmodel
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">artifact_path: grid-random-forest-model
# flavors:
#   python_function:
#     data: model.pkl
#     env: conda.yaml
#     loader_module: mlflow.sklearn
#     python_version: 3.7.3
#   sklearn:
#     pickled_model: model.pkl
#     serialization_format: cloudpickle
#     sklearn_version: 0.20.3
# run_id: c2e07b090d4b417c86eb8a8704e118ea
# utc_time_created: '2020-04-07 17:49:52.692361'
#
# </div>

# %% [markdown]
# -sandbox
# <img alt="Side Note" title="Side Note" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.05em; transform:rotate(15deg)" src="https://files.training.databricks.com/static/images/icon-note.webp"/> See the solutions folder for an example solution to this lab.

# %% [markdown]
# ## ![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) Classroom-Cleanup<br>
#
# Run the **`Classroom-Cleanup`** cell below to remove any artifacts created by this lesson.

# %%
# %run "../Includes/Classroom-Cleanup"

# %% [markdown]
# ## ![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) Next Steps
#
# Start the next lesson, [Packaging ML Projects]($../03-Packaging-ML-Projects ).

# %% [markdown]
# -sandbox
# &copy; 2020 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the <a href="http://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/>
# <a href="https://databricks.com/privacy-policy">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use">Terms of Use</a> | <a href="http://help.databricks.com/">Support</a>
