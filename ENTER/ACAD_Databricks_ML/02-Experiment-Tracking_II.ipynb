# %% [markdown]
# d-sandbox
#
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning" style="width: 600px; height: 163px">
# </div>

# %% [markdown]
# # Experiment Tracking
#
# The machine learning life cycle involves training multiple algorithms using different hyperparameters and libraries, all with different performance results and trained models.  This lesson explores tracking those experiments to organize the machine learning life cycle.
#
# ## ![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) In this lesson you:<br>
#  - Introduce tracking ML experiments in MLflow
#  - Log an experiment and explore the results in the UI
#  - Record parameters, metrics, and a model
#  - Query past runs programatically

# %% [markdown]
# ## ![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) Classroom-Setup & Classroom-Cleanup<br>
#
# For each lesson to execute correctly, please make sure to run the **`Classroom-Setup`** cell at the start of each lesson (see the next cell) and the **`Classroom-Cleanup`** cell at the end of each lesson.

# %%
# %run "./Includes/Classroom-Setup"

# %% [markdown]
# <iframe
# src="//fast.wistia.net/embed/iframe/pc07a7t7xe?videoFoam=true"
# style="border:1px solid #1cb1c2;"
# allowtransparency="true" scrolling="no" class="wistia_embed"
# name="wistia_embed" allowfullscreen mozallowfullscreen webkitallowfullscreen
# oallowfullscreen msallowfullscreen width="640" height="360" ></iframe>
# <div>
# <a target="_blank" href="https://fast.wistia.net/embed/iframe/pc07a7t7xe?seo=false">
#   <img alt="Opens in new tab" src="https://files.training.databricks.com/static/images/external-link-icon-16x16.png"/>&nbsp;Watch full-screen.</a>
# </div>

# %% [markdown]
# -sandbox
# ### Tracking Experiments with MLflow
#
# Over the course of the machine learning life cycle, data scientists test many different models from various libraries with different hyperparameters.  Tracking these various results poses an organizational challenge.  In brief, storing experiments, results, models, supplementary artifacts, and code creates significant challenges.
#
# MLflow Tracking is one of the three main components of MLflow.  It is a logging API specific for machine learning and agnostic to libraries and environments that do the training.  It is organized around the concept of **runs**, which are executions of data science code.  Runs are aggregated into **experiments** where many runs can be a part of a given experiment and an MLflow server can host many experiments.
#
# Each run can record the following information:<br><br>
#
# - **Parameters:** Key-value pairs of input parameters such as the number of trees in a random forest model
# - **Metrics:** Evaluation metrics such as RMSE or Area Under the ROC Curve
# - **Artifacts:** Arbitrary output files in any format.  This can include images, pickled models, and data files
# - **Source:** The code that originally ran the experiment
#
# MLflow tracking also serves as a **model registry** so tracked models can easily be stored and, as necessary, deployed into production.
#
# Experiments can be tracked using libraries in Python, R, and Java as well as by using the CLI and REST calls.  This course will use Python, though the majority of MLflow functionality is also exposed in these other APIs.
#
# <div><img src="https://files.training.databricks.com/images/eLearning/ML-Part-4/mlflow-tracking.png" style="height: 400px; margin: 20px"/></div>

# %% [markdown]
# -sandbox
# ### Experiment Logging and UI
#
# MLflow is an open source software project developed by Databricks available to developers regardless of which platform they are using.  Databricks hosts MLflow for you, which reduces deployment configuration and adds security benefits.  It is accessible on all Databricks workspaces in Azure and AWS.  It is not currently enabled on Community Edition
#
# <img alt="Side Note" title="Side Note" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.05em; transform:rotate(15deg)" src="https://files.training.databricks.com/static/images/icon-note.webp"/> See <a href="https://mlflow.org/docs/latest/quickstart.html#" target="_blank">the MLflow quickstart guide</a> for details on setting up MLflow locally or on your own server.

# %% [markdown]
# Databricks uses two different versions of its software.  The **Databricks Runtime** does not currently come with MLflow pre-installed.  if you are using Databricks runtime, uncomment the code below and run it to install `mlflow`.

# %%
#######################################################################
#                                                                     #
#    This installs MLflow for you only on Databricks Runtime          #
#    NOTE: this code does not work with ML runtime (see below)        #
#                                                                     #
#######################################################################


dbutils.library.installPyPI("mlflow", "1.0.0")
dbutils.library.restartPython()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# The other version of Databricks is the **Machine Learning Runtime,** which you'll notice has `ML` next to the cluster type.  **Machine Learning Runtime has `mlflow` pre-installed starting at version 5.5.**  If you have runtime **5.5 ML or later** available to you, you do not need to install `mlflow`.
#
# If your version of Machine Learning Runtime is lower than 5.5, please install the library `mlflow==1.0.0` using `PyPi` manually.  <a href="https://files.training.databricks.com/static/step-by-step/installing-libraries-from-pypi.html" target="_blank">See the instructions on how to install a library from PyPi</a> if you're unfamiliar with the process

# %% [markdown]
# Import a dataset of Airbnb listings and featurize the data.  We'll use this to train a model.

# %%
import pandas as pd

df = pd.read_csv("/dbfs/mnt/training/airbnb/sf-listings/airbnb-cleaned-mlflow.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>host_total_listings_count</th>
#       <th>neighbourhood_cleansed</th>
#       <th>zipcode</th>
#       <th>latitude</th>
#       <th>longitude</th>
#       <th>property_type</th>
#       <th>room_type</th>
#       <th>accommodates</th>
#       <th>bathrooms</th>
#       <th>bedrooms</th>
#       <th>beds</th>
#       <th>bed_type</th>
#       <th>minimum_nights</th>
#       <th>number_of_reviews</th>
#       <th>review_scores_rating</th>
#       <th>review_scores_accuracy</th>
#       <th>review_scores_cleanliness</th>
#       <th>review_scores_checkin</th>
#       <th>review_scores_communication</th>
#       <th>review_scores_location</th>
#       <th>review_scores_value</th>
#       <th>price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>37.769310</td>
#       <td>-122.433856</td>
#       <td>0</td>
#       <td>0</td>
#       <td>3.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>0</td>
#       <td>1.0</td>
#       <td>127.0</td>
#       <td>97.0</td>
#       <td>10.0</td>
#       <td>10.0</td>
#       <td>10.0</td>
#       <td>10.0</td>
#       <td>10.0</td>
#       <td>10.0</td>
#       <td>170.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2.0</td>
#       <td>1</td>
#       <td>1</td>
#       <td>37.745112</td>
#       <td>-122.421018</td>
#       <td>0</td>
#       <td>0</td>
#       <td>5.0</td>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>3.0</td>
#       <td>0</td>
#       <td>30.0</td>
#       <td>112.0</td>
#       <td>98.0</td>
#       <td>10.0</td>
#       <td>10.0</td>
#       <td>10.0</td>
#       <td>10.0</td>
#       <td>10.0</td>
#       <td>9.0</td>
#       <td>235.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>10.0</td>
#       <td>2</td>
#       <td>0</td>
#       <td>37.766690</td>
#       <td>-122.452505</td>
#       <td>0</td>
#       <td>1</td>
#       <td>2.0</td>
#       <td>4.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>0</td>
#       <td>32.0</td>
#       <td>17.0</td>
#       <td>85.0</td>
#       <td>8.0</td>
#       <td>8.0</td>
#       <td>9.0</td>
#       <td>9.0</td>
#       <td>9.0</td>
#       <td>8.0</td>
#       <td>65.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4.0</td>
#       <td>3</td>
#       <td>2</td>
#       <td>37.730746</td>
#       <td>-122.448409</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>0</td>
#       <td>3.0</td>
#       <td>76.0</td>
#       <td>95.0</td>
#       <td>9.0</td>
#       <td>9.0</td>
#       <td>10.0</td>
#       <td>10.0</td>
#       <td>9.0</td>
#       <td>9.0</td>
#       <td>60.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>10.0</td>
#       <td>2</td>
#       <td>0</td>
#       <td>37.764872</td>
#       <td>-122.451828</td>
#       <td>1</td>
#       <td>1</td>
#       <td>2.0</td>
#       <td>4.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>0</td>
#       <td>32.0</td>
#       <td>7.0</td>
#       <td>91.0</td>
#       <td>9.0</td>
#       <td>9.0</td>
#       <td>9.0</td>
#       <td>9.0</td>
#       <td>9.0</td>
#       <td>9.0</td>
#       <td>65.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Perform a train/test split.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df.drop(["price"], axis=1), df[["price"]].values.ravel(), random_state=42)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# -sandbox
# **Navigate to the MLflow UI by clicking on the `Runs` button on the top of the screen.**
#
# <img alt="Side Note" title="Side Note" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.05em; transform:rotate(15deg)" src="https://files.training.databricks.com/static/images/icon-note.webp"/> Every Python notebook in a Azure Databricks Workspace has its own experiment. When you use MLflow in a notebook, it records runs in the notebook experiment. A notebook experiment shares the same name and ID as its corresponding notebook.

# %% [markdown]
# Log a basic experiment by doing the following:<br><br>
#
# 1. Start an experiment using `mlflow.start_run()` and passing it a name for the run
# 2. Train your model
# 3. Log the model using `mlflow.sklearn.log_model()`
# 4. Log the model error using `mlflow.log_metric()`
# 5. Print out the run id using `run.info.run_uuid`

# %%
import mlflow.sklearn
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# start the experiment using mflow.start_run() and passing it a name for the run 
with mlflow.start_run(run_name="Basic RF Experiment") as run:
  # Create model, train it, and create predictions
  rf = RandomForestRegressor()
  rf.fit(X_train, y_train)
  predictions = rf.predict(X_test)
  
  
  #  Log model
  #  Log the model using mlflow.sklearn.log_model()
  mlflow.sklearn.log_model(rf, "random-forest-model")
  

  # Create metrics
  mse = mean_squared_error(y_test, predictions)
  print("  mse: {}".format(mse))
  
  
  #  Log metrics
  #  Log the model error using mlflow.log_metric()
  mlflow.log_metric("mse", mse)
  
  #  Print out the run id using run.info.run_uuid:  
  runID = run.info.run_uuid  #  need to dir it ... 
  experimentID = run.info.experiment_id
  
  
  print("Inside MLflow Run with run_id {} and experiment_id {}".format(runID, experimentID))
  
  
  #   Inside MLflow Run with run_id 99f9b40f1842491fb49ede485299a145 and experiment_id 2056266854505353
  #
  #
  #
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/python/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   &#34;10 in version 0.20 to 100 in 0.22.&#34;, FutureWarning)
#   mse: 6460.2577315208155
# Inside MLflow Run with run_id a59fb0cf7998431f88a997daa380deb3 and experiment_id 2056266854505353
# </div>

# %%
mlflow
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[5]: &lt;module &#39;mlflow&#39; from &#39;/local_disk0/pythonVirtualEnvDirs/virtualEnv-d70e4295-8b5e-415f-95fd-780f31f73e04/lib/python3.7/site-packages/mlflow/__init__.py&#39;&gt;</div>

# %% [markdown]
# <br><br><br>

# %%
dir(mlflow)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[6]: [&#39;ActiveRun&#39;,
#  &#39;__all__&#39;,
#  &#39;__builtins__&#39;,
#  &#39;__cached__&#39;,
#  &#39;__doc__&#39;,
#  &#39;__file__&#39;,
#  &#39;__loader__&#39;,
#  &#39;__name__&#39;,
#  &#39;__package__&#39;,
#  &#39;__path__&#39;,
#  &#39;__spec__&#39;,
#  &#39;__version__&#39;,
#  &#39;_configure_mlflow_loggers&#39;,
#  &#39;active_run&#39;,
#  &#39;create_experiment&#39;,
#  &#39;data&#39;,
#  &#39;end_run&#39;,
#  &#39;entities&#39;,
#  &#39;exceptions&#39;,
#  &#39;get_artifact_uri&#39;,
#  &#39;get_tracking_uri&#39;,
#  &#39;log_artifact&#39;,
#  &#39;log_artifacts&#39;,
#  &#39;log_metric&#39;,
#  &#39;log_metrics&#39;,
#  &#39;log_param&#39;,
#  &#39;log_params&#39;,
#  &#39;mlflow&#39;,
#  &#39;models&#39;,
#  &#39;projects&#39;,
#  &#39;protos&#39;,
#  &#39;pyfunc&#39;,
#  &#39;run&#39;,
#  &#39;set_experiment&#39;,
#  &#39;set_tag&#39;,
#  &#39;set_tags&#39;,
#  &#39;set_tracking_uri&#39;,
#  &#39;sklearn&#39;,
#  &#39;start_run&#39;,
#  &#39;store&#39;,
#  &#39;tracking&#39;,
#  &#39;utils&#39;,
#  &#39;version&#39;,
#  &#39;warnings&#39;]</div>

# %%
"""
 'active_run',
 'create_experiment',
 'data',
 'end_run',
 'entities',
 'exceptions',
 'get_artifact_uri',
 'get_tracking_uri',
 'log_artifact',
 'log_artifacts',
 'log_metric',
 'log_metrics',
 'log_param',
 'log_params',
 'mlflow',
 'models',
 'projects',
 'protos',
 'pyfunc',
 'run',
 'set_experiment',
 'set_tag',
 'set_tags',
 'set_tracking_uri',
 'sklearn',
 'start_run',
 'store',
 'tracking',
 'utils',
 'version',
 'warnings']
 """
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[7]: &#34;\n &#39;active_run&#39;,\n &#39;create_experiment&#39;,\n &#39;data&#39;,\n &#39;end_run&#39;,\n &#39;entities&#39;,\n &#39;exceptions&#39;,\n &#39;get_artifact_uri&#39;,\n &#39;get_tracking_uri&#39;,\n &#39;log_artifact&#39;,\n &#39;log_artifacts&#39;,\n &#39;log_metric&#39;,\n &#39;log_metrics&#39;,\n &#39;log_param&#39;,\n &#39;log_params&#39;,\n &#39;mlflow&#39;,\n &#39;models&#39;,\n &#39;projects&#39;,\n &#39;protos&#39;,\n &#39;pyfunc&#39;,\n &#39;run&#39;,\n &#39;set_experiment&#39;,\n &#39;set_tag&#39;,\n &#39;set_tags&#39;,\n &#39;set_tracking_uri&#39;,\n &#39;sklearn&#39;,\n &#39;start_run&#39;,\n &#39;store&#39;,\n &#39;tracking&#39;,\n &#39;utils&#39;,\n &#39;version&#39;,\n &#39;warnings&#39;]\n &#34;</div>

# %%
mlflow.version
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[10]: &lt;module &#39;mlflow.version&#39; from &#39;/local_disk0/pythonVirtualEnvDirs/virtualEnv-d70e4295-8b5e-415f-95fd-780f31f73e04/lib/python3.7/site-packages/mlflow/version.py&#39;&gt;</div>

# %%
dir(run)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[11]: [&#39;__class__&#39;,
#  &#39;__delattr__&#39;,
#  &#39;__dict__&#39;,
#  &#39;__dir__&#39;,
#  &#39;__doc__&#39;,
#  &#39;__enter__&#39;,
#  &#39;__eq__&#39;,
#  &#39;__exit__&#39;,
#  &#39;__format__&#39;,
#  &#39;__ge__&#39;,
#  &#39;__getattribute__&#39;,
#  &#39;__gt__&#39;,
#  &#39;__hash__&#39;,
#  &#39;__init__&#39;,
#  &#39;__init_subclass__&#39;,
#  &#39;__iter__&#39;,
#  &#39;__le__&#39;,
#  &#39;__lt__&#39;,
#  &#39;__module__&#39;,
#  &#39;__ne__&#39;,
#  &#39;__new__&#39;,
#  &#39;__reduce__&#39;,
#  &#39;__reduce_ex__&#39;,
#  &#39;__repr__&#39;,
#  &#39;__setattr__&#39;,
#  &#39;__sizeof__&#39;,
#  &#39;__str__&#39;,
#  &#39;__subclasshook__&#39;,
#  &#39;__weakref__&#39;,
#  &#39;_data&#39;,
#  &#39;_info&#39;,
#  &#39;_properties&#39;,
#  &#39;data&#39;,
#  &#39;from_dictionary&#39;,
#  &#39;from_proto&#39;,
#  &#39;info&#39;,
#  &#39;to_dictionary&#39;,
#  &#39;to_proto&#39;]</div>

# %%
"""
 'data',
 'from_dictionary',
 'from_proto',
 'info',
 'to_dictionary',
 'to_proto']
"""
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[12]: &#34;\n &#39;data&#39;,\n &#39;from_dictionary&#39;,\n &#39;from_proto&#39;,\n &#39;info&#39;,\n &#39;to_dictionary&#39;,\n &#39;to_proto&#39;]\n&#34;</div>

# %%
print(run.info)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;RunInfo: artifact_uri=&#39;dbfs:/databricks/mlflow/2056266854505353/a59fb0cf7998431f88a997daa380deb3/artifacts&#39;, end_time=None, experiment_id=&#39;2056266854505353&#39;, lifecycle_stage=&#39;active&#39;, run_id=&#39;a59fb0cf7998431f88a997daa380deb3&#39;, run_uuid=&#39;a59fb0cf7998431f88a997daa380deb3&#39;, start_time=1586274670891, status=&#39;RUNNING&#39;, user_id=&#39;&#39;&gt;
# </div>

# %%
print(run.info.end_time)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">None
# </div>

# %%
run.info.run_id
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[16]: &#39;a59fb0cf7998431f88a997daa380deb3&#39;</div>

# %%
run.info.status
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[17]: &#39;RUNNING&#39;</div>

# %%
run.info.start_time
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[18]: 1586274670891</div>

# %%
run.info.user_id
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[19]: &#39;&#39;</div>

# %%
run.info.experiment_id
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[20]: &#39;2056266854505353&#39;</div>

# %%
run.info.artifact_uri   ##################################################################
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[22]: &#39;dbfs:/databricks/mlflow/2056266854505353/a59fb0cf7998431f88a997daa380deb3/artifacts&#39;</div>

# %%
# MLModel:
  
# artifact_path: random-forest-model
# flavors:
#   python_function:
#     data: model.pkl
#     env: conda.yaml
#     loader_module: mlflow.sklearn
#     python_version: 3.7.3
#   sklearn:
#     pickled_model: model.pkl
#     serialization_format: cloudpickle
#     sklearn_version: 0.20.3
# run_id: a59fb0cf7998431f88a997daa380deb3
# utc_time_created: '2020-04-07 15:51:11.418205'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# channels:
# - defaults
# dependencies:
# - python=3.7.3
# - scikit-learn=0.20.3
# - pip:
#   - mlflow
#   - cloudpickle==1.3.0
# name: mlflow-env

# %%
# Artifact:
#   Random Forest Model:
#     Full Path: dbfs:/databricks/mlflow/2056266854505353/a59fb0cf7998431f88a997daa380deb3/artifacts/random-forest-model
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# <br><br><br>

# %% [markdown]
# d-sandbox
#
# Examine the results in the UI.  Look for the following:<br><br>
#
# 1. The `Experiment ID`
# 2. The artifact location.  This is where the artifacts are stored in DBFS, which is backed by the Azure blob store
# 3. The time the run was executed.  **Click this timestamp to see more information on the run.**
# 4. The code that executed the run.
#
# <div><img src="https://files.training.databricks.com/images/eLearning/ML-Part-4/mlflow-ui-lesson2.png" style="height: 400px; margin: 20px"/></div>

# %% [markdown]
# -sandbox
# After clicking on the time of the run, take a look at the following:<br><br>
#
# 1. The Run ID will match what we printed above
# 2. The model that we saved, included a picked version of the model as well as the Conda environment and the `MLmodel` file, which will be discussed in the next lesson.
#
# <div><img src="https://files.training.databricks.com/images/eLearning/ML-Part-4/mlflow-ui-lesson2b.png" style="height: 400px; margin: 20px"/></div>

# %% [markdown]
# Now take a look at the directory structure backing this experiment.  This allows you to retrieve artifacts.

# %% [markdown]
# -sandbox
# This is a comment within the md-sandbox magic command...

# %% [markdown]
# This is a comment within the md magic command...

# %%
# ML MODEL:

# artifact_path: random-forest-model
#-----------------------------------
# flavors:
#   python_function:
#     data: model.pkl
#     env: conda.yaml
#     loader_module: mlflow.sklearn
#     python_version: 3.7.3
#   sklearn:
#     pickled_model: model.pkl
#     serialization_format: cloudpickle
#     sklearn_version: 0.20.3
#
# run_id: 99f9b40f1842491fb49ede485299a145
# utc_time_created: '2020-04-06 21:01:43.470689'

# %%
#
# conda.yml:
#
# channels:
# - defaults
# dependencies:
# - python=3.7.3
# - scikit-learn=0.20.3
# - pip:
#   - mlflow
#   - cloudpickle==1.3.0
# name: mlflow-env
#

# %%
#

# %%
# Full Path: dbfs:/databricks/mlflow/2056266854505353/a59fb0cf7998431f88a997daa380deb3/artifacts/random-forest-model/model.pkl
# Full Path: dbfs:/databricks/mlflow/2056266854505353/a59fb0cf7998431f88a997daa380deb3/artifacts/random-forest-model/model.pkl
# Full Path: dbfs:/databricks/mlflow/2056266854505353/a59fb0cf7998431f88a997daa380deb3/artifacts/random-forest-model/conda.yaml
# Full Path: dbfs:/databricks/mlflow/2056266854505353/a59fb0cf7998431f88a997daa380deb3/artifacts/random-forest-model/MLmodel

# %%
# %fs head dbfs:/databricks/mlflow/2056266854505353/a59fb0cf7998431f88a997daa380deb3/artifacts/random-forest-model/conda.yaml
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">channels:
# - defaults
# dependencies:
# - python=3.7.3
# - scikit-learn=0.20.3
# - pip:
#   - mlflow
#   - cloudpickle==1.3.0
# name: mlflow-env
#
# </div>

# %%
# %fs head dbfs:/databricks/mlflow/2056266854505353/a59fb0cf7998431f88a997daa380deb3/artifacts/random-forest-model/conda.yaml
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">channels:
# - defaults
# dependencies:
# - python=3.7.3
# - scikit-learn=0.20.3
# - pip:
#   - mlflow
#   - cloudpickle==1.3.0
# name: mlflow-env
#
# </div>

# %%
from mlflow.tracking import MlflowClient

artifactURL = MlflowClient().get_experiment(experimentID).artifact_location

dbutils.fs.ls(artifactURL)


#     Full Path: dbfs:/databricks/mlflow/2056266854505353/a59fb0cf7998431f88a997daa380deb3/artifacts/random-forest-model
# FileInfo(path='dbfs:/databricks/mlflow/2056266854505353/a59fb0cf7998431f88a997daa380deb3/', name='a59fb0cf7998431f88a997daa380deb3/', size=0),
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[28]: [FileInfo(path=&#39;dbfs:/databricks/mlflow/2056266854505353/0692d3af9b0d4b268a62afa20af85088/&#39;, name=&#39;0692d3af9b0d4b268a62afa20af85088/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/databricks/mlflow/2056266854505353/99f9b40f1842491fb49ede485299a145/&#39;, name=&#39;99f9b40f1842491fb49ede485299a145/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/databricks/mlflow/2056266854505353/a59fb0cf7998431f88a997daa380deb3/&#39;, name=&#39;a59fb0cf7998431f88a997daa380deb3/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/databricks/mlflow/2056266854505353/e1c0bb6196e44816993399b5b860f041/&#39;, name=&#39;e1c0bb6196e44816993399b5b860f041/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/databricks/mlflow/2056266854505353/e5fd6a396c5c46d8aa3597587172f0fc/&#39;, name=&#39;e5fd6a396c5c46d8aa3597587172f0fc/&#39;, size=0)]</div>

# %%
display(dbutils.fs.ls(artifactURL))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/databricks/mlflow/2056266854505353/0692d3af9b0d4b268a62afa20af85088/</td><td>0692d3af9b0d4b268a62afa20af85088/</td><td>0</td></tr><tr><td>dbfs:/databricks/mlflow/2056266854505353/99f9b40f1842491fb49ede485299a145/</td><td>99f9b40f1842491fb49ede485299a145/</td><td>0</td></tr><tr><td>dbfs:/databricks/mlflow/2056266854505353/a59fb0cf7998431f88a997daa380deb3/</td><td>a59fb0cf7998431f88a997daa380deb3/</td><td>0</td></tr><tr><td>dbfs:/databricks/mlflow/2056266854505353/e1c0bb6196e44816993399b5b860f041/</td><td>e1c0bb6196e44816993399b5b860f041/</td><td>0</td></tr><tr><td>dbfs:/databricks/mlflow/2056266854505353/e5fd6a396c5c46d8aa3597587172f0fc/</td><td>e5fd6a396c5c46d8aa3597587172f0fc/</td><td>0</td></tr></tbody></table></div>

# %% [markdown]
# Take a look at the contents of `random-forest-model`, which match what we see in the UI.

# %%
modelURL = artifactURL + "/" + runID + "/artifacts/random-forest-model"
dbutils.fs.ls(modelURL)

# so basically:
#  i ran a model
#   all the parameters and files are saved within a set folder
#    each run will have this...
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[29]: [FileInfo(path=&#39;dbfs:/databricks/mlflow/2056266854505353/a59fb0cf7998431f88a997daa380deb3/artifacts/random-forest-model/MLmodel&#39;, name=&#39;MLmodel&#39;, size=357),
#  FileInfo(path=&#39;dbfs:/databricks/mlflow/2056266854505353/a59fb0cf7998431f88a997daa380deb3/artifacts/random-forest-model/conda.yaml&#39;, name=&#39;conda.yaml&#39;, size=130),
#  FileInfo(path=&#39;dbfs:/databricks/mlflow/2056266854505353/a59fb0cf7998431f88a997daa380deb3/artifacts/random-forest-model/model.pkl&#39;, name=&#39;model.pkl&#39;, size=2526380)]</div>

# %%
display(dbutils.fs.ls(modelURL))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/databricks/mlflow/2056266854505353/a59fb0cf7998431f88a997daa380deb3/artifacts/random-forest-model/MLmodel</td><td>MLmodel</td><td>357</td></tr><tr><td>dbfs:/databricks/mlflow/2056266854505353/a59fb0cf7998431f88a997daa380deb3/artifacts/random-forest-model/conda.yaml</td><td>conda.yaml</td><td>130</td></tr><tr><td>dbfs:/databricks/mlflow/2056266854505353/a59fb0cf7998431f88a997daa380deb3/artifacts/random-forest-model/model.pkl</td><td>model.pkl</td><td>2526380</td></tr></tbody></table></div>

# %% [markdown]
# <br><br><br>

# %% [markdown]
# -sandbox
# ### Parameters, Metrics, and Artifacts
#
# But wait, there's more!  In the last example, you logged the run name, an evaluation metric, and your model itself as an artifact.  Now let's log parameters, multiple metrics, and other artifacts including the feature importances.
#
# First, create a function to perform this.
#
# <img alt="Side Note" title="Side Note" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.05em; transform:rotate(15deg)" src="https://files.training.databricks.com/static/images/icon-note.webp"/> To log artifacts, we have to save them somewhere before MLflow can log them.  This code accomplishes that by using a temporary file that it then deletes.

# %%
# EXPLAIN ...



def log_rf(experimentID, run_name, params, X_train, X_test, y_train, y_test):
  import os
  import matplotlib.pyplot as plt
  import mlflow.sklearn
  import seaborn as sns
  from sklearn.ensemble import RandomForestRegressor
  from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
  import tempfile

  with mlflow.start_run(experiment_id=experimentID, run_name=run_name) as run:
    # Create model, train it, and create predictions
    rf = RandomForestRegressor(**params)
    rf.fit(X_train, y_train)
    predictions = rf.predict(X_test)

    # Log model
    # LOG MODEL ! 
    mlflow.sklearn.log_model(rf, "random-forest-model")  # < 

    
    
    # Log params
    [mlflow.log_param(param, value) for param, value in params.items()]

    
    
    # Create metrics
    # CREATE METRICS:
    mse = mean_squared_error(y_test, predictions)
    mae = mean_absolute_error(y_test, predictions)
    r2 = r2_score(y_test, predictions)
    print("  mse: {}".format(mse))
    print("  mae: {}".format(mae))
    print("  R2: {}".format(r2))

    
    
    # LOG METRICS: 
    # Log metrics
    mlflow.log_metric("mse", mse)
    mlflow.log_metric("mae", mae)  
    mlflow.log_metric("r2", r2)  
    
    
    
    # Create feature importance
    importance = pd.DataFrame(list(zip(df.columns, rf.feature_importances_)), 
                                columns=["Feature", "Importance"]
                              ).sort_values("Importance", ascending=False)
    
    
    # Log importances using a temporary file
    temp = tempfile.NamedTemporaryFile(prefix="feature-importance-", suffix=".csv")
    temp_name = temp.name
    try:
      importance.to_csv(temp_name, index=False)
      mlflow.log_artifact(temp_name, "feature-importance.csv")
    finally:
      temp.close() # Delete the temp file
    
    # Create plot
    fig, ax = plt.subplots()

    sns.residplot(predictions, y_test, lowess=True)
    plt.xlabel("Predicted values for Price ($)")
    plt.ylabel("Residual")
    plt.title("Residual Plot")

    # Log residuals using a temporary file
    temp = tempfile.NamedTemporaryFile(prefix="residuals-", suffix=".png")
    temp_name = temp.name
    try:
      fig.savefig(temp_name)
      mlflow.log_artifact(temp_name, "residuals.png")
    finally:
      temp.close() # Delete the temp file
      
    display(fig)
    return run.info.run_uuid
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Run with new parameters.

# %%
params = {
  "n_estimators": 100,
  "max_depth": 5,
  "random_state": 42
}

log_rf(experimentID, "Second Run", params, X_train, X_test, y_train, y_test)

#  THIS IS A BRAND NEW RUN ! ! ! !

# %%
# dbfs:/databricks/mlflow/2056266854505353/52d4f97628f6486bb0db969a2b668066/artifacts/feature-importance.csv/feature-importance
 

# Feature,Importance
# bedrooms,0.5949576004054734
# bathrooms,0.11661760180724536
# latitude,0.07844484281295888
# room_type,0.06335837054773166
# accommodates,0.053453816195459226
# review_scores_rating,0.014701991543567572
# host_total_listings_count,0.013551494422392379
# longitude,0.013010087073085848
# property_type,0.00895818744726431
# number_of_reviews,0.008565137633517279
# neighbourhood_cleansed,0.007077426123493789
# bed_type,0.0066783265757615895
# review_scores_cleanliness,0.0054202385550012
# beds,0.004623533397174171
# zipcode,0.004323343562264181
# minimum_nights,0.004051366066858625
# review_scores_location,0.0013054993100623008
# review_scores_accuracy,0.0007215736930094966
# review_scores_value,0.0001379661204427594
# review_scores_checkin,4.1003397997616526e-05
# review_scores_communication,5.933092382107802e-07

# %%
# %fs ls dbfs:/databricks/mlflow/2056266854505353/52d4f97628f6486bb0db969a2b668066/artifacts/feature-importance.csv
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/databricks/mlflow/2056266854505353/52d4f97628f6486bb0db969a2b668066/artifacts/feature-importance.csv/feature-importance-ph1l1lgm.csv</td><td>feature-importance-ph1l1lgm.csv</td><td>801</td></tr></tbody></table></div>

# %%
# %fs head dbfs:/databricks/mlflow/2056266854505353/52d4f97628f6486bb0db969a2b668066/artifacts/feature-importance.csv/feature-importance-ph1l1lgm.csv
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Feature,Importance
# bedrooms,0.5949576004054734
# bathrooms,0.11661760180724536
# latitude,0.07844484281295888
# room_type,0.06335837054773166
# accommodates,0.053453816195459226
# review_scores_rating,0.014701991543567572
# host_total_listings_count,0.013551494422392379
# longitude,0.013010087073085848
# property_type,0.00895818744726431
# number_of_reviews,0.008565137633517279
# neighbourhood_cleansed,0.007077426123493789
# bed_type,0.0066783265757615895
# review_scores_cleanliness,0.0054202385550012
# beds,0.004623533397174171
# zipcode,0.004323343562264181
# minimum_nights,0.004051366066858625
# review_scores_location,0.0013054993100623008
# review_scores_accuracy,0.0007215736930094966
# review_scores_value,0.0001379661204427594
# review_scores_checkin,4.1003397997616526e-05
# review_scores_communication,5.933092382107802e-07
#
# </div>

# %% [markdown]
# Check the UI to see how this appears.  Take a look at the artifact to see where the plot was saved.
#
# Now, run a third run.

# %%
params_1000_trees = {
  "n_estimators": 1000,
  "max_depth": 10,
  "random_state": 42
}

log_rf(experimentID, "Third Run", params_1000_trees, X_train, X_test, y_train, y_test)

# %%
type(params_1000_trees)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[35]: dict</div>

# %%
# always do this, very helpful ! ! ! ! 
for key,value in run.info:
  print(key, " ------------->  ", value)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">artifact_uri  -------------&gt;   dbfs:/databricks/mlflow/2056266854505353/a59fb0cf7998431f88a997daa380deb3/artifacts
# end_time  -------------&gt;   None
# experiment_id  -------------&gt;   2056266854505353
# lifecycle_stage  -------------&gt;   active
# run_id  -------------&gt;   a59fb0cf7998431f88a997daa380deb3
# run_uuid  -------------&gt;   a59fb0cf7998431f88a997daa380deb3
# start_time  -------------&gt;   1586274670891
# status  -------------&gt;   RUNNING
# user_id  -------------&gt;
# </div>

# %%
# always do this, very helpful ! ! ! ! 
for key,value in run.info:
  print(key, "\t\t", value)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">artifact_uri 		 dbfs:/databricks/mlflow/2056266854505353/a59fb0cf7998431f88a997daa380deb3/artifacts
# end_time 		 None
# experiment_id 		 2056266854505353
# lifecycle_stage 		 active
# run_id 		 a59fb0cf7998431f88a997daa380deb3
# run_uuid 		 a59fb0cf7998431f88a997daa380deb3
# start_time 		 1586274670891
# status 		 RUNNING
# user_id
# </div>

# %% [markdown]
# -sandbox
# ### Querying Past Runs
#
# You can query past runs programatically in order to use this data back in Python.  The pathway to doing this is an `MlflowClient` object.
#
# <img alt="Side Note" title="Side Note" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.05em; transform:rotate(15deg)" src="https://files.training.databricks.com/static/images/icon-note.webp"/> You can also set tags for runs using `client.set_tag(run.info.run_uuid, "tag_key", "tag_value")`

# %%
from  mlflow.tracking import MlflowClient

client = MlflowClient()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
client
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[41]: &lt;mlflow.tracking.client.MlflowClient at 0x7fde67492d68&gt;</div>

# %%
type(client)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[42]: mlflow.tracking.client.MlflowClient</div>

# %%
dir(client)


#    'create_experiment',
#    'create_run',
#    'delete_experiment',
#    'delete_run',
#    'download_artifacts',
#    'get_experiment',
#    'get_experiment_by_name',
#    'get_metric_history',
#    'get_run',
#    'list_artifacts',
#    'list_experiments',
#    'list_run_infos',
#    'log_artifact',
#    'log_artifacts',
#    'log_batch',
#    'log_metric',
#    'log_param',
#    'rename_experiment',
#    'restore_experiment',
#    'restore_run',
#    'search_runs',
#    'set_tag',
#    'set_terminated',
#    'store',
#    'tracking_uri']

# %%
client.tracking_uri
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[43]: &#39;databricks&#39;</div>

# %%
dir(client)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[44]: [&#39;__class__&#39;,
#  &#39;__delattr__&#39;,
#  &#39;__dict__&#39;,
#  &#39;__dir__&#39;,
#  &#39;__doc__&#39;,
#  &#39;__eq__&#39;,
#  &#39;__format__&#39;,
#  &#39;__ge__&#39;,
#  &#39;__getattribute__&#39;,
#  &#39;__gt__&#39;,
#  &#39;__hash__&#39;,
#  &#39;__init__&#39;,
#  &#39;__init_subclass__&#39;,
#  &#39;__le__&#39;,
#  &#39;__lt__&#39;,
#  &#39;__module__&#39;,
#  &#39;__ne__&#39;,
#  &#39;__new__&#39;,
#  &#39;__reduce__&#39;,
#  &#39;__reduce_ex__&#39;,
#  &#39;__repr__&#39;,
#  &#39;__setattr__&#39;,
#  &#39;__sizeof__&#39;,
#  &#39;__str__&#39;,
#  &#39;__subclasshook__&#39;,
#  &#39;__weakref__&#39;,
#  &#39;create_experiment&#39;,
#  &#39;create_run&#39;,
#  &#39;delete_experiment&#39;,
#  &#39;delete_run&#39;,
#  &#39;download_artifacts&#39;,
#  &#39;get_experiment&#39;,
#  &#39;get_experiment_by_name&#39;,
#  &#39;get_metric_history&#39;,
#  &#39;get_run&#39;,
#  &#39;list_artifacts&#39;,
#  &#39;list_experiments&#39;,
#  &#39;list_run_infos&#39;,
#  &#39;log_artifact&#39;,
#  &#39;log_artifacts&#39;,
#  &#39;log_batch&#39;,
#  &#39;log_metric&#39;,
#  &#39;log_param&#39;,
#  &#39;rename_experiment&#39;,
#  &#39;restore_experiment&#39;,
#  &#39;restore_run&#39;,
#  &#39;search_runs&#39;,
#  &#39;set_tag&#39;,
#  &#39;set_terminated&#39;,
#  &#39;store&#39;,
#  &#39;tracking_uri&#39;]</div>

# %%
client.log_metric
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[45]: &lt;bound method MlflowClient.log_metric of &lt;mlflow.tracking.client.MlflowClient object at 0x7fde67492d68&gt;&gt;</div>

# %% [markdown]
# Now list all the runs for your experiment using `.list_run_infos()`, which takes your `experiment_id` as a parameter.

# %%
client.list_run_infos(experimentID)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[46]: [&lt;RunInfo: artifact_uri=&#39;dbfs:/databricks/mlflow/2056266854505353/e7169212308a4e8396a4d3ffeb481871/artifacts&#39;, end_time=1586276462189, experiment_id=&#39;2056266854505353&#39;, lifecycle_stage=&#39;active&#39;, run_id=&#39;e7169212308a4e8396a4d3ffeb481871&#39;, run_uuid=&#39;e7169212308a4e8396a4d3ffeb481871&#39;, start_time=1586276428565, status=&#39;FINISHED&#39;, user_id=&#39;&#39;&gt;,
#  &lt;RunInfo: artifact_uri=&#39;dbfs:/databricks/mlflow/2056266854505353/52d4f97628f6486bb0db969a2b668066/artifacts&#39;, end_time=1586275848969, experiment_id=&#39;2056266854505353&#39;, lifecycle_stage=&#39;active&#39;, run_id=&#39;52d4f97628f6486bb0db969a2b668066&#39;, run_uuid=&#39;52d4f97628f6486bb0db969a2b668066&#39;, start_time=1586275842673, status=&#39;FINISHED&#39;, user_id=&#39;&#39;&gt;,
#  &lt;RunInfo: artifact_uri=&#39;dbfs:/databricks/mlflow/2056266854505353/a59fb0cf7998431f88a997daa380deb3/artifacts&#39;, end_time=1586274675249, experiment_id=&#39;2056266854505353&#39;, lifecycle_stage=&#39;active&#39;, run_id=&#39;a59fb0cf7998431f88a997daa380deb3&#39;, run_uuid=&#39;a59fb0cf7998431f88a997daa380deb3&#39;, start_time=1586274670891, status=&#39;FINISHED&#39;, user_id=&#39;&#39;&gt;,
#  &lt;RunInfo: artifact_uri=&#39;dbfs:/databricks/mlflow/2056266854505353/e1c0bb6196e44816993399b5b860f041/artifacts&#39;, end_time=1586208316971, experiment_id=&#39;2056266854505353&#39;, lifecycle_stage=&#39;active&#39;, run_id=&#39;e1c0bb6196e44816993399b5b860f041&#39;, run_uuid=&#39;e1c0bb6196e44816993399b5b860f041&#39;, start_time=1586208286256, status=&#39;FINISHED&#39;, user_id=&#39;&#39;&gt;,
#  &lt;RunInfo: artifact_uri=&#39;dbfs:/databricks/mlflow/2056266854505353/0692d3af9b0d4b268a62afa20af85088/artifacts&#39;, end_time=1586208199845, experiment_id=&#39;2056266854505353&#39;, lifecycle_stage=&#39;active&#39;, run_id=&#39;0692d3af9b0d4b268a62afa20af85088&#39;, run_uuid=&#39;0692d3af9b0d4b268a62afa20af85088&#39;, start_time=1586208192747, status=&#39;FINISHED&#39;, user_id=&#39;&#39;&gt;,
#  &lt;RunInfo: artifact_uri=&#39;dbfs:/databricks/mlflow/2056266854505353/e5fd6a396c5c46d8aa3597587172f0fc/artifacts&#39;, end_time=1586207031649, experiment_id=&#39;2056266854505353&#39;, lifecycle_stage=&#39;active&#39;, run_id=&#39;e5fd6a396c5c46d8aa3597587172f0fc&#39;, run_uuid=&#39;e5fd6a396c5c46d8aa3597587172f0fc&#39;, start_time=1586207029133, status=&#39;FINISHED&#39;, user_id=&#39;&#39;&gt;,
#  &lt;RunInfo: artifact_uri=&#39;dbfs:/databricks/mlflow/2056266854505353/99f9b40f1842491fb49ede485299a145/artifacts&#39;, end_time=1586206908899, experiment_id=&#39;2056266854505353&#39;, lifecycle_stage=&#39;active&#39;, run_id=&#39;99f9b40f1842491fb49ede485299a145&#39;, run_uuid=&#39;99f9b40f1842491fb49ede485299a145&#39;, start_time=1586206902955, status=&#39;FINISHED&#39;, user_id=&#39;&#39;&gt;]</div>

# %%
client.list_experiments
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[47]: &lt;bound method MlflowClient.list_experiments of &lt;mlflow.tracking.client.MlflowClient object at 0x7fde67492d68&gt;&gt;</div>

# %%
display(client.list_run_infos(experimentID))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_artifact_uri</th><th>_end_time</th><th>_experiment_id</th><th>_lifecycle_stage</th><th>_run_id</th><th>_run_uuid</th><th>_start_time</th><th>_status</th><th>_user_id</th></tr></thead><tbody><tr><td>dbfs:/databricks/mlflow/2056266854505353/e7169212308a4e8396a4d3ffeb481871/artifacts</td><td>1586276462189</td><td>2056266854505353</td><td>active</td><td>e7169212308a4e8396a4d3ffeb481871</td><td>e7169212308a4e8396a4d3ffeb481871</td><td>1586276428565</td><td>FINISHED</td><td></td></tr><tr><td>dbfs:/databricks/mlflow/2056266854505353/52d4f97628f6486bb0db969a2b668066/artifacts</td><td>1586275848969</td><td>2056266854505353</td><td>active</td><td>52d4f97628f6486bb0db969a2b668066</td><td>52d4f97628f6486bb0db969a2b668066</td><td>1586275842673</td><td>FINISHED</td><td></td></tr><tr><td>dbfs:/databricks/mlflow/2056266854505353/a59fb0cf7998431f88a997daa380deb3/artifacts</td><td>1586274675249</td><td>2056266854505353</td><td>active</td><td>a59fb0cf7998431f88a997daa380deb3</td><td>a59fb0cf7998431f88a997daa380deb3</td><td>1586274670891</td><td>FINISHED</td><td></td></tr><tr><td>dbfs:/databricks/mlflow/2056266854505353/e1c0bb6196e44816993399b5b860f041/artifacts</td><td>1586208316971</td><td>2056266854505353</td><td>active</td><td>e1c0bb6196e44816993399b5b860f041</td><td>e1c0bb6196e44816993399b5b860f041</td><td>1586208286256</td><td>FINISHED</td><td></td></tr><tr><td>dbfs:/databricks/mlflow/2056266854505353/0692d3af9b0d4b268a62afa20af85088/artifacts</td><td>1586208199845</td><td>2056266854505353</td><td>active</td><td>0692d3af9b0d4b268a62afa20af85088</td><td>0692d3af9b0d4b268a62afa20af85088</td><td>1586208192747</td><td>FINISHED</td><td></td></tr><tr><td>dbfs:/databricks/mlflow/2056266854505353/e5fd6a396c5c46d8aa3597587172f0fc/artifacts</td><td>1586207031649</td><td>2056266854505353</td><td>active</td><td>e5fd6a396c5c46d8aa3597587172f0fc</td><td>e5fd6a396c5c46d8aa3597587172f0fc</td><td>1586207029133</td><td>FINISHED</td><td></td></tr><tr><td>dbfs:/databricks/mlflow/2056266854505353/99f9b40f1842491fb49ede485299a145/artifacts</td><td>1586206908899</td><td>2056266854505353</td><td>active</td><td>99f9b40f1842491fb49ede485299a145</td><td>99f9b40f1842491fb49ede485299a145</td><td>1586206902955</td><td>FINISHED</td><td></td></tr></tbody></table></div>

# %% [markdown]
# Pull out a few fields and create a pandas DataFrame with it.

# %%
runs = pd.DataFrame([(run.run_uuid, run.start_time, run.artifact_uri) for run in client.list_run_infos(experimentID)])
runs.columns = ["run_uuid", "start_time", "artifact_uri"]
display(runs)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>run_uuid</th><th>start_time</th><th>artifact_uri</th></tr></thead><tbody><tr><td>e7169212308a4e8396a4d3ffeb481871</td><td>1586276428565</td><td>dbfs:/databricks/mlflow/2056266854505353/e7169212308a4e8396a4d3ffeb481871/artifacts</td></tr><tr><td>52d4f97628f6486bb0db969a2b668066</td><td>1586275842673</td><td>dbfs:/databricks/mlflow/2056266854505353/52d4f97628f6486bb0db969a2b668066/artifacts</td></tr><tr><td>a59fb0cf7998431f88a997daa380deb3</td><td>1586274670891</td><td>dbfs:/databricks/mlflow/2056266854505353/a59fb0cf7998431f88a997daa380deb3/artifacts</td></tr><tr><td>e1c0bb6196e44816993399b5b860f041</td><td>1586208286256</td><td>dbfs:/databricks/mlflow/2056266854505353/e1c0bb6196e44816993399b5b860f041/artifacts</td></tr><tr><td>0692d3af9b0d4b268a62afa20af85088</td><td>1586208192747</td><td>dbfs:/databricks/mlflow/2056266854505353/0692d3af9b0d4b268a62afa20af85088/artifacts</td></tr><tr><td>e5fd6a396c5c46d8aa3597587172f0fc</td><td>1586207029133</td><td>dbfs:/databricks/mlflow/2056266854505353/e5fd6a396c5c46d8aa3597587172f0fc/artifacts</td></tr><tr><td>99f9b40f1842491fb49ede485299a145</td><td>1586206902955</td><td>dbfs:/databricks/mlflow/2056266854505353/99f9b40f1842491fb49ede485299a145/artifacts</td></tr></tbody></table></div>

# %% [markdown]
# Pull the last run and take a look at the associated artifacts.

# %%
last_run = runs.sort_values("start_time", ascending=False).iloc[0]

dbutils.fs.ls(last_run["artifact_uri"]+"/random-forest-model/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[50]: [FileInfo(path=&#39;dbfs:/databricks/mlflow/2056266854505353/e7169212308a4e8396a4d3ffeb481871/artifacts/random-forest-model/MLmodel&#39;, name=&#39;MLmodel&#39;, size=357),
#  FileInfo(path=&#39;dbfs:/databricks/mlflow/2056266854505353/e7169212308a4e8396a4d3ffeb481871/artifacts/random-forest-model/conda.yaml&#39;, name=&#39;conda.yaml&#39;, size=130),
#  FileInfo(path=&#39;dbfs:/databricks/mlflow/2056266854505353/e7169212308a4e8396a4d3ffeb481871/artifacts/random-forest-model/model.pkl&#39;, name=&#39;model.pkl&#39;, size=46665877)]</div>

# %% [markdown]
# Return the evaluation metrics for the last run.

# %%
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

client.get_run(last_run.run_uuid).data.metrics
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[51]: {&#39;mae&#39;: 48.82679545743182, &#39;mse&#39;: 6013.141341974693, &#39;r2&#39;: 0.7063859458544959}</div>

# %% [markdown]
# Reload the model and take a look at the feature importance.

# %%
display(dbutils.fs.ls(last_run.artifact_uri))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/databricks/mlflow/2056266854505353/e7169212308a4e8396a4d3ffeb481871/artifacts/feature-importance.csv/</td><td>feature-importance.csv/</td><td>0</td></tr><tr><td>dbfs:/databricks/mlflow/2056266854505353/e7169212308a4e8396a4d3ffeb481871/artifacts/random-forest-model/</td><td>random-forest-model/</td><td>0</td></tr><tr><td>dbfs:/databricks/mlflow/2056266854505353/e7169212308a4e8396a4d3ffeb481871/artifacts/residuals.png/</td><td>residuals.png/</td><td>0</td></tr></tbody></table></div>

# %%
import mlflow.sklearn

model = mlflow.sklearn.load_model(last_run.artifact_uri + "/random-forest-model/")
model.feature_importances_

##################### !
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[53]: array([0.02066125, 0.01968234, 0.01714745, 0.10652883, 0.0466081 ,
#        0.0197694 , 0.04940956, 0.05043625, 0.09587796, 0.45534329,
#        0.01225107, 0.00644477, 0.01970861, 0.03186636, 0.0288097 ,
#        0.00256674, 0.00629972, 0.00134757, 0.0006453 , 0.00505837,
#        0.00353737])</div>

# %% [markdown]
# ## Review
# **Question:** What can MLflow Tracking log?
# **Answer:** MLflow can log the following:
# - **Parameters:** inputs to a model
# - **Metrics:** the performance of the model
# - **Artifacts:** any object including data, models, and images
# - **Source:** the original code, including the commit hash if linked to git
#
# **Question:** How do you log experiments?
# **Answer:** Experiments are logged by first creating a run and using the logging methods on that run object (e.g. `run.log_param("MSE", .2)`).
#
# **Question:** Where do logged artifacts get saved?
# **Answer:** Logged artifacts are saved in a directory of your choosing.  On Databricks, this would be DBFS, or the Databricks File System, which backed by a blob store.
#
# **Question:** How can I query past runs?
# **Answer:** This can be done using an `MlflowClient` object.  This allows you do everything you can within the UI programatically so you never have to step outside of your programming environment.

# %% [markdown]
# ## ![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) Classroom-Cleanup<br>
#
# Run the **`Classroom-Cleanup`** cell below to remove any artifacts created by this lesson.

# %%
# %run "./Includes/Classroom-Cleanup"

# %%
#  %run "./Includes/Classroom-Setup"

# %% [markdown]
# ## ![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) Next Steps
#
# Start the labs for this lesson, [Experiment Tracking Lab]($./Labs/02-Lab)

# %% [markdown]
# ## Additional Topics & Resources
#
# **Q:** What is MLflow at a high level?
# **A:** <a href="https://databricks.com/session/accelerating-the-machine-learning-lifecycle-with-mlflow-1-0" target="_blank">Listen to Spark and MLflow creator Matei Zaharia's talk at Spark Summit in 2019.</a>
#
# **Q:** What is a good source for the larger context of machine learning tools?
# **A:** <a href="https://roaringelephant.org/2019/06/18/episode-145-alex-zeltov-on-mlops-with-mlflow-kubeflow-and-other-tools-part-1/#more-1958" target="_blank">Check out this episode of the podcast Roaring Elephant.</a>
#
# **Q:** Where can I find the MLflow docs?
# **A:** <a href="https://www.mlflow.org/docs/latest/index.html" target="_blank">You can find the docs here.</a>
#
# **Q:** What is a good general resource for machine learning?
# **A:** <a href="https://www-bcf.usc.edu/~gareth/ISL/" target="_blank">_An Introduction to Statistical Learning_</a> is a good starting point for the themes and basic approaches to machine learning.
#
# **Q:** Where can I find out more information on machine learning with Spark?
# **A:** Check out the Databricks blog <a href="https://databricks.com/blog/category/engineering/machine-learning" target="_blank">dedicated to machine learning</a>

# %% [markdown]
# -sandbox
# &copy; 2020 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the <a href="http://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/>
# <a href="https://databricks.com/privacy-policy">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use">Terms of Use</a> | <a href="http://help.databricks.com/">Support</a>
