# %% [markdown]
# d-sandbox
#
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning" style="width: 600px; height: 163px">
# </div>

# %% [markdown]
# -sandbox
# <img src="https://files.training.databricks.com/images/Apache-Spark-Logo_TM_200px.png" style="float: left: margin: 20px"/>
#
# # Joins and Lookup Tables
#
# Apache Spark&trade; and Databricks&reg; allow you to join new records to existing tables in an ETL job.
#
# ## In this lesson you:
# * Join new records to a pre-existing lookup table
# * Employ table join best practices relevant to big data environments
#
# ## Audience
# * Primary Audience: Data Engineers
# * Additional Audiences: Data Scientists and Data Pipeline Engineers
#
# ## Prerequisites
# * Web browser: Chrome
# * Course: ETL Part 1 from <a href="https://academy.databricks.com/" target="_blank">Databricks Academy</a>

# %% [markdown]
# ## ![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) Classroom-Setup & Classroom-Cleanup<br>
#
# For each lesson to execute correctly, please make sure to run the **`Classroom-Setup`** cell at the start of each lesson (see the next cell) and the **`Classroom-Cleanup`** cell at the end of each lesson.

# %%
# %run "./Includes/Classroom-Setup"

# %% [markdown]
# <iframe
# src="//fast.wistia.net/embed/iframe/pvwi0sdvwu?videoFoam=true"
# style="border:1px solid #1cb1c2;"
# allowtransparency="true" scrolling="no" class="wistia_embed"
# name="wistia_embed" allowfullscreen mozallowfullscreen webkitallowfullscreen
# oallowfullscreen msallowfullscreen width="640" height="360" ></iframe>
# <div>
# <a target="_blank" href="https://fast.wistia.net/embed/iframe/pvwi0sdvwu?seo=false">
#   <img alt="Opens in new tab" src="https://files.training.databricks.com/static/images/external-link-icon-16x16.png"/>&nbsp;Watch full-screen.</a>
# </div>

# %% [markdown]
# -sandbox
# ### Shuffle and Broadcast Joins
#
# A common use case in ETL jobs involves joining new data to either lookup tables or historical data. You need different considerations to guide this process when working with distributed technologies such as Spark, rather than traditional databases that sit on a single machine.
#
# Traditional databases join tables by pairing values on a given column. When all the data sits in a single database, it often goes unnoticed how computationally expensive row-wise comparisons are.  When data is distributed across a cluster, the expense of joins becomes even more apparent.
#
# **A standard (or shuffle) join** moves all the data on the cluster for each table to a given node on the cluster. This is expensive not only because of the computation needed to perform row-wise comparisons, but also because data transfer across a network is often the biggest performance bottleneck of distributed systems.
#
# By contrast, **a broadcast join** remedies this situation when one DataFrame is sufficiently small. A broadcast join duplicates the smaller of the two DataFrames on each node of the cluster, avoiding the cost of shuffling the bigger DataFrame.
#
# <div><img src="https://files.training.databricks.com/images/eLearning/ETL-Part-2/shuffle-and-broadcast-joins.png" style="height: 400px; margin: 20px"/></div>

# %% [markdown]
# ### Lookup Tables
#
# Lookup tables are normally small, historical tables used to enrich new data passing through an ETL pipeline.

# %% [markdown]
# Import a small table that will enrich new data coming into a pipeline.

# %%
# %fs ls  /mnt/training/day-of-week/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/mnt/training/day-of-week/_SUCCESS</td><td>_SUCCESS</td><td>0</td></tr><tr><td>dbfs:/mnt/training/day-of-week/_committed_8408431661997702124</td><td>_committed_8408431661997702124</td><td>116</td></tr><tr><td>dbfs:/mnt/training/day-of-week/_started_8408431661997702124</td><td>_started_8408431661997702124</td><td>0</td></tr><tr><td>dbfs:/mnt/training/day-of-week/part-00000-tid-8408431661997702124-21692399-214e-4737-b4d1-8b16fdafaf11-0-c000.gz.parquet</td><td>part-00000-tid-8408431661997702124-21692399-214e-4737-b4d1-8b16fdafaf11-0-c000.gz.parquet</td><td>1125</td></tr></tbody></table></div>

# %%
# %fs head /mnt/training/day-of-week/part-00000-tid-8408431661997702124-21692399-214e-4737-b4d1-8b16fdafaf11-0-c000.gz.parquet
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# .���Tnr,WedFri�cb```�g���y *�4D����yE ʭ(D'����&lt;s�6y7Zb,WF�cb```�g��L@&quot;��33@L738L��n�-\Hspark_schema%dow%longName%%abbreviated%%	shortName%L&amp;%dowz�&amp;&lt;&amp;�5longName��&amp;�&lt;	WednesdayFriday&amp;�5abbreviated��&amp;�&lt;WedFri&amp;�5	shortName��&amp;�&lt;WF�)org.apache.spark.sql.parquet.row.metadata�{&quot;type&quot;:&quot;struct&quot;,&quot;fields&quot;:[{&quot;name&quot;:&quot;dow&quot;,&quot;type&quot;:&quot;integer&quot;,&quot;nullable&quot;:false,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;longName&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;abbreviated&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;shortName&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}}]}Iparquet-mr version 1.8.2 (build c6522788629e590a53eb79874b95f6c3ff11f16c)�PAR1
# </div>

# %%
labelsDF = spark.read.parquet("/mnt/training/day-of-week")
display(labelsDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>dow</th><th>longName</th><th>abbreviated</th><th>shortName</th></tr></thead><tbody><tr><td>1</td><td>Monday</td><td>Mon</td><td>M</td></tr><tr><td>2</td><td>Tuesday</td><td>Tue</td><td>Tu</td></tr><tr><td>3</td><td>Wednesday</td><td>Wed</td><td>W</td></tr><tr><td>4</td><td>Thursday</td><td>Thr</td><td>Th</td></tr><tr><td>5</td><td>Friday</td><td>Fri</td><td>F</td></tr><tr><td>6</td><td>Saturday</td><td>Sat</td><td>Sa</td></tr><tr><td>7</td><td>Sunday</td><td>Sun</td><td>Su</td></tr></tbody></table></div>

# %%
labelsDF.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[14]:
+
# only showing top 10 rows
#
# </div>

# %% [markdown]
# Now aggregate the results to see trends by day of the week.
#
# :NOTE: `pageviewsEnhancedDF` is a large DataFrame so it can take a while to process depending on the size of your cluster.

# %%
from pyspark.sql.functions import col

aggregatedDowDF = (pageviewsEnhancedDF
  .groupBy(col("dow"), col("longName"), col("abbreviated"), col("shortName"))  
  .sum("requests")                                             
  .withColumnRenamed("sum(requests)", "Requests")
  .orderBy(col("dow"))
)

display(aggregatedDowDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>dow</th><th>longName</th><th>abbreviated</th><th>shortName</th><th>Requests</th></tr></thead><tbody><tr><td>1</td><td>Monday</td><td>Mon</td><td>M</td><td>2356818845</td></tr><tr><td>2</td><td>Tuesday</td><td>Tue</td><td>Tu</td><td>1995034884</td></tr><tr><td>3</td><td>Wednesday</td><td>Wed</td><td>W</td><td>1977615396</td></tr><tr><td>4</td><td>Thursday</td><td>Thr</td><td>Th</td><td>1931508977</td></tr><tr><td>5</td><td>Friday</td><td>Fri</td><td>F</td><td>1842512718</td></tr><tr><td>6</td><td>Saturday</td><td>Sat</td><td>Sa</td><td>1662762048</td></tr><tr><td>7</td><td>Sunday</td><td>Sun</td><td>Su</td><td>1576726066</td></tr></tbody></table></div>

# %% [markdown]
# -sandbox
# ### Exploring Broadcast Joins
#
# In joining these two DataFrames together, no type of join was specified.  In order to examine this, look at the physical plan used to return the query. This can be done with the `.explain()` DataFrame method. Look for **BroadcastHashJoin** and/or **BroadcastExchange**.
#
# <div><img src="https://files.training.databricks.com/images/eLearning/ETL-Part-2/broadcasthashjoin.png" style="height: 400px; margin: 20px"/></div>

# %%
aggregatedDowDF.explain()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">== Physical Plan ==
# Sort [dow#11258 ASC NULLS FIRST], true, 0
# +- Exchange rangepartitioning(dow#11258 ASC NULLS FIRST, 200), [id=#13638]
#    +- *(3) Project [dow#11258, longName#11213, abbreviated#11214, shortName#11215, sum(cast(requests#11253 as bigint))#11319L AS Requests#11326L]
#       +- *(3) HashAggregate(keys=[dow#11258, longName#11213, abbreviated#11214, shortName#11215], functions=[finalmerge_sum(merge sum#11338L) AS sum(cast(requests#11253 as bigint))#11319L])
#          +- Exchange hashpartitioning(dow#11258, longName#11213, abbreviated#11214, shortName#11215, 200), [id=#13633]
#             +- *(2) HashAggregate(keys=[dow#11258, longName#11213, abbreviated#11214, shortName#11215], functions=[merge_sum(merge sum#11338L) AS sum#11338L])
#                +- *(2) BroadcastHashJoin [cast(dow#11258 as int)], [dow#11212], Inner, BuildRight
#                   :- *(2) HashAggregate(keys=[dow#11258], functions=[partial_sum(cast(requests#11253 as bigint)) AS sum#11338L])
#                   :  +- *(2) Project [requests#11253, date_format(cast(timestamp#11251 as timestamp), u, Some(Etc/UTC)) AS dow#11258]
#                   :     +- *(2) Filter isnotnull(date_format(cast(timestamp#11251 as timestamp), u, Some(Etc/UTC)))
#                   :        +- *(2) FileScan parquet [timestamp#11251,requests#11253] Batched: true, DataFilters: [isnotnull(date_format(cast(timestamp#11251 as timestamp), u, Some(Etc/UTC)))], Format: Parquet, Location: InMemoryFileIndex[dbfs:/mnt/training/wikipedia/pageviews/pageviews_by_second.parquet], PartitionFilters: [], PushedFilters: [], ReadSchema: struct&lt;timestamp:string,requests:int&gt;
#                   +- BroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint))), [id=#13628]
#                      +- *(1) Project [dow#11212, longName#11213, abbreviated#11214, shortName#11215]
#                         +- *(1) Filter isnotnull(dow#11212)
#                            +- *(1) FileScan parquet [dow#11212,longName#11213,abbreviated#11214,shortName#11215] Batched: true, DataFilters: [isnotnull(dow#11212)], Format: Parquet, Location: InMemoryFileIndex[dbfs:/mnt/training/day-of-week], PartitionFilters: [], PushedFilters: [IsNotNull(dow)], ReadSchema: struct&lt;dow:int,longName:string,abbreviated:string,shortName:string&gt;
# </div>

# %% [markdown]
# By default, Spark did a broadcast join rather than a shuffle join.  In other words, it broadcast `labelsDF` to the larger `pageviewsDF`, replicating the smaller DataFrame on each node of our cluster.  This avoided having to move the larger DataFrame across the cluster.
#
# Take a look at the broadcast threshold by accessing the configuration settings.

# %%
### this is important ! ! ! ! 

#  it takes the small and replicates/broadcasts onto the larger areas
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
threshold = spark.conf.get("spark.sql.autoBroadcastJoinThreshold")
print("Threshold: {0:,}".format( int(threshold) ))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Threshold: 10,485,760
# </div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">Py4JJavaError</span>                             Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-2724779091453152&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      1</span>
# <span class="ansi-green-fg">----&gt; 2</span><span class="ansi-red-fg"> </span>dir<span class="ansi-blue-fg">(</span>spark<span class="ansi-blue-fg">.</span>conf<span class="ansi-blue-fg">.</span>get<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;spark.sql&#34;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/conf.py</span> in <span class="ansi-cyan-fg">get</span><span class="ansi-blue-fg">(self, key, default)</span>
# <span class="ansi-green-intense-fg ansi-bold">     49</span>         self<span class="ansi-blue-fg">.</span>_checkType<span class="ansi-blue-fg">(</span>key<span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">&#34;key&#34;</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">     50</span>         <span class="ansi-green-fg">if</span> default <span class="ansi-green-fg">is</span> _NoValue<span class="ansi-blue-fg">:</span>
# <span class="ansi-green-fg">---&gt; 51</span><span class="ansi-red-fg">             </span><span class="ansi-green-fg">return</span> self<span class="ansi-blue-fg">.</span>_jconf<span class="ansi-blue-fg">.</span>get<span class="ansi-blue-fg">(</span>key<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">     52</span>         <span class="ansi-green-fg">else</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">     53</span>             <span class="ansi-green-fg">if</span> default <span class="ansi-green-fg">is</span> <span class="ansi-green-fg">not</span> <span class="ansi-green-fg">None</span><span class="ansi-blue-fg">:</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py</span> in <span class="ansi-cyan-fg">__call__</span><span class="ansi-blue-fg">(self, *args)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1255</span>         answer <span class="ansi-blue-fg">=</span> self<span class="ansi-blue-fg">.</span>gateway_client<span class="ansi-blue-fg">.</span>send_command<span class="ansi-blue-fg">(</span>command<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1256</span>         return_value = get_return_value(
# <span class="ansi-green-fg">-&gt; 1257</span><span class="ansi-red-fg">             answer, self.gateway_client, self.target_id, self.name)
# </span><span class="ansi-green-intense-fg ansi-bold">   1258</span>
# <span class="ansi-green-intense-fg ansi-bold">   1259</span>         <span class="ansi-green-fg">for</span> temp_arg <span class="ansi-green-fg">in</span> temp_args<span class="ansi-blue-fg">:</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/utils.py</span> in <span class="ansi-cyan-fg">deco</span><span class="ansi-blue-fg">(*a, **kw)</span>
# <span class="ansi-green-intense-fg ansi-bold">     61</span>     <span class="ansi-green-fg">def</span> deco<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">*</span>a<span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">**</span>kw<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">     62</span>         <span class="ansi-green-fg">try</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-fg">---&gt; 63</span><span class="ansi-red-fg">             </span><span class="ansi-green-fg">return</span> f<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">*</span>a<span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">**</span>kw<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">     64</span>         <span class="ansi-green-fg">except</span> py4j<span class="ansi-blue-fg">.</span>protocol<span class="ansi-blue-fg">.</span>Py4JJavaError <span class="ansi-green-fg">as</span> e<span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">     65</span>             s <span class="ansi-blue-fg">=</span> e<span class="ansi-blue-fg">.</span>java_exception<span class="ansi-blue-fg">.</span>toString<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/lib/py4j-0.10.7-src.zip/py4j/protocol.py</span> in <span class="ansi-cyan-fg">get_return_value</span><span class="ansi-blue-fg">(answer, gateway_client, target_id, name)</span>
# <span class="ansi-green-intense-fg ansi-bold">    326</span>                 raise Py4JJavaError(
# <span class="ansi-green-intense-fg ansi-bold">    327</span>                     <span class="ansi-blue-fg">&#34;An error occurred while calling {0}{1}{2}.\n&#34;</span><span class="ansi-blue-fg">.</span>
# <span class="ansi-green-fg">--&gt; 328</span><span class="ansi-red-fg">                     format(target_id, &#34;.&#34;, name), value)
# </span><span class="ansi-green-intense-fg ansi-bold">    329</span>             <span class="ansi-green-fg">else</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">    330</span>                 raise Py4JError(
#
# <span class="ansi-red-fg">Py4JJavaError</span>: An error occurred while calling o237.get.
# : java.util.NoSuchElementException: spark.sql
# 	at org.apache.spark.sql.internal.SQLConf$$anonfun$getConfString$2.apply(SQLConf.scala:2256)
# 	at org.apache.spark.sql.internal.SQLConf$$anonfun$getConfString$2.apply(SQLConf.scala:2256)
# 	at scala.Option.getOrElse(Option.scala:121)
# 	at org.apache.spark.sql.internal.SQLConf.getConfString(SQLConf.scala:2256)
# 	at org.apache.spark.sql.RuntimeConfig.get(RuntimeConfig.scala:75)
# 	at sun.reflect.GeneratedMethodAccessor658.invoke(Unknown Source)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:380)
# 	at py4j.Gateway.invoke(Gateway.java:295)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:251)
# 	at java.lang.Thread.run(Thread.java:748)
# </div>

# %% [markdown]
# This is the maximize size in bytes for a table that broadcast to worker nodes.  Dropping it to `-1` disables broadcasting.

# %%
spark.conf.set("spark.sql.autoBroadcastJoinThreshold", -1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Now notice the lack of broadcast in the query physical plan.

# %%
pageviewsDF.join(labelsDF, "dow").explain()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">== Physical Plan ==
# *(3) Project [dow#11258, timestamp#11251, site#11252, requests#11253, longName#11213, abbreviated#11214, shortName#11215]
# +- *(3) SortMergeJoin [cast(dow#11258 as int)], [dow#11212], Inner
#    :- Sort [cast(dow#11258 as int) ASC NULLS FIRST], false, 0
#    :  +- Exchange hashpartitioning(cast(dow#11258 as int), 200), [id=#13732]
#    :     +- *(1) Project [timestamp#11251, site#11252, requests#11253, date_format(cast(timestamp#11251 as timestamp), u, Some(Etc/UTC)) AS dow#11258]
#    :        +- *(1) Filter isnotnull(date_format(cast(timestamp#11251 as timestamp), u, Some(Etc/UTC)))
#    :           +- *(1) FileScan parquet [timestamp#11251,site#11252,requests#11253] Batched: true, DataFilters: [isnotnull(date_format(cast(timestamp#11251 as timestamp), u, Some(Etc/UTC)))], Format: Parquet, Location: InMemoryFileIndex[dbfs:/mnt/training/wikipedia/pageviews/pageviews_by_second.parquet], PartitionFilters: [], PushedFilters: [], ReadSchema: struct&lt;timestamp:string,site:string,requests:int&gt;
#    +- Sort [dow#11212 ASC NULLS FIRST], false, 0
#       +- Exchange hashpartitioning(dow#11212, 200), [id=#13736]
#          +- *(2) Project [dow#11212, longName#11213, abbreviated#11214, shortName#11215]
#             +- *(2) Filter isnotnull(dow#11212)
#                +- *(2) FileScan parquet [dow#11212,longName#11213,abbreviated#11214,shortName#11215] Batched: true, DataFilters: [isnotnull(dow#11212)], Format: Parquet, Location: InMemoryFileIndex[dbfs:/mnt/training/day-of-week], PartitionFilters: [], PushedFilters: [IsNotNull(dow)], ReadSchema: struct&lt;dow:int,longName:string,abbreviated:string,shortName:string&gt;
# </div>

# %% [markdown]
# Next reset the original threshold.

# %%
spark.conf.set("spark.sql.autoBroadcastJoinThreshold", threshold)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Explicitly Broadcasting Tables
#
# There are two ways of telling Spark to explicitly broadcast tables. The first is to change the Spark configuration, which affects all operations. The second is to declare it using the `broadcast()` function in the `functions` package.

# %%
from pyspark.sql.functions import broadcast

pageviewsDF.join(broadcast(labelsDF), "dow").explain()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">== Physical Plan ==
# *(2) Project [dow#11258, timestamp#11251, site#11252, requests#11253, longName#11213, abbreviated#11214, shortName#11215]
# +- *(2) BroadcastHashJoin [cast(dow#11258 as int)], [dow#11212], Inner, BuildRight
#    :- *(2) Project [timestamp#11251, site#11252, requests#11253, date_format(cast(timestamp#11251 as timestamp), u, Some(Etc/UTC)) AS dow#11258]
#    :  +- *(2) Filter isnotnull(date_format(cast(timestamp#11251 as timestamp), u, Some(Etc/UTC)))
#    :     +- *(2) FileScan parquet [timestamp#11251,site#11252,requests#11253] Batched: true, DataFilters: [isnotnull(date_format(cast(timestamp#11251 as timestamp), u, Some(Etc/UTC)))], Format: Parquet, Location: InMemoryFileIndex[dbfs:/mnt/training/wikipedia/pageviews/pageviews_by_second.parquet], PartitionFilters: [], PushedFilters: [], ReadSchema: struct&lt;timestamp:string,site:string,requests:int&gt;
#    +- BroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, true] as bigint))), [id=#13801]
#       +- *(1) Project [dow#11212, longName#11213, abbreviated#11214, shortName#11215]
#          +- *(1) Filter isnotnull(dow#11212)
#             +- *(1) FileScan parquet [dow#11212,longName#11213,abbreviated#11214,shortName#11215] Batched: true, DataFilters: [isnotnull(dow#11212)], Format: Parquet, Location: InMemoryFileIndex[dbfs:/mnt/training/day-of-week], PartitionFilters: [], PushedFilters: [IsNotNull(dow)], ReadSchema: struct&lt;dow:int,longName:string,abbreviated:string,shortName:string&gt;
# </div>

# %% [markdown]
# ## Exercise 1: Join a Lookup Table
#
# Join a table that includes country name to a lookup table containing the full country name.

# %% [markdown]
# ### Step 1: Import the Data
#
# Create the following DataFrames:<br><br>
#
# - `countryLookupDF`: A lookup table with ISO country codes located at `/mnt/training/countries/ISOCountryCodes/ISOCountryLookup.parquet`
# - `logWithIPDF`: A server log including the results from an IPLookup table located at `/mnt/training/EDGAR-Log-20170329/enhanced/logDFwithIP.parquet`

# %%
# TODO
countryLookupDF = spark.read.parquet("/mnt/training/countries/ISOCountryCodes/ISOCountryLookup.parquet")
logWithIPDF = spark.read.parquet("/mnt/training/EDGAR-Log-20170329/enhanced/logDFwithIP.parquet")

display(countryLookupDF)
display(logWithIPDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ip</th><th>date</th><th>time</th><th>zone</th><th>cik</th><th>accession</th><th>extention</th><th>code</th><th>size</th><th>idx</th><th>norefer</th><th>noagent</th><th>find</th><th>crawler</th><th>browser</th><th>IPLookupISO2</th></tr></thead><tbody><tr><td>101.71.41.ihh</td><td>2017-03-29</td><td>00:00:00</td><td>0.0</td><td>1437491.0</td><td>0001245105-17-000052</td><td>xslF345X03/primary_doc.xml</td><td>301.0</td><td>687.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>10.0</td><td>0.0</td><td>null</td><td>CN</td></tr><tr><td>104.196.240.dda</td><td>2017-03-29</td><td>00:00:00</td><td>0.0</td><td>1270985.0</td><td>0001188112-04-001037</td><td>.txt</td><td>200.0</td><td>7619.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>10.0</td><td>0.0</td><td>null</td><td>US</td></tr><tr><td>107.23.85.jfd</td><td>2017-03-29</td><td>00:00:00</td><td>0.0</td><td>1059376.0</td><td>0000905148-07-006108</td><td>-index.htm</td><td>200.0</td><td>2727.0</td><td>1.0</td><td>0.0</td><td>0.0</td><td>10.0</td><td>0.0</td><td>null</td><td>US</td></tr><tr><td>107.23.85.jfd</td><td>2017-03-29</td><td>00:00:00</td><td>0.0</td><td>1059376.0</td><td>0000905148-08-001993</td><td>-index.htm</td><td>200.0</td><td>2710.0</td><td>1.0</td><td>0.0</td><td>0.0</td><td>10.0</td><td>0.0</td><td>null</td><td>US</td></tr><tr><td>107.23.85.jfd</td><td>2017-03-29</td><td>00:00:00</td><td>0.0</td><td>1059376.0</td><td>0001104659-09-046963</td><td>-index.htm</td><td>200.0</td><td>2715.0</td><td>1.0</td><td>0.0</td><td>0.0</td><td>10.0</td><td>0.0</td><td>null</td><td>US</td></tr><tr><td>107.23.85.jfd</td><td>2017-03-29</td><td>00:00:00</td><td>0.0</td><td>1364986.0</td><td>0000914121-06-002243</td><td>-index.htm</td><td>200.0</td><td>2786.0</td><td>1.0</td><td>0.0</td><td>0.0</td><td>10.0</td><td>0.0</td><td>null</td><td>US</td></tr><tr><td>107.23.85.jfd</td><td>2017-03-29</td><td>00:00:00</td><td>0.0</td><td>1364986.0</td><td>0000914121-06-002251</td><td>-index.htm</td><td>200.0</td><td>2784.0</td><td>1.0</td><td>0.0</td><td>0.0</td><td>10.0</td><td>0.0</td><td>null</td><td>US</td></tr><tr><td>108.240.248.gha</td><td>2017-03-29</td><td>00:00:00</td><td>0.0</td><td>1540159.0</td><td>0001217160-12-000029</td><td>f332scottlease.htm</td><td>200.0</td><td>49578.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>10.0</td><td>0.0</td><td>null</td><td>US</td></tr><tr><td>108.59.8.fef</td><td>2017-03-29</td><td>00:00:00</td><td>0.0</td><td>732834.0</td><td>0001209191-15-017349</td><td>xslF345X03/doc4.xml</td><td>301.0</td><td>673.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>10.0</td><td>0.0</td><td>null</td><td>US</td></tr><tr><td>108.91.91.hbc</td><td>2017-03-29</td><td>00:00:00</td><td>0.0</td><td>1629769.0</td><td>0001209191-17-023204</td><td>.txt</td><td>301.0</td><td>675.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>10.0</td><td>0.0</td><td>null</td><td>US</td></tr><tr><td>108.91.91.hbc</td><td>2017-03-29</td><td>00:00:00</td><td>0.0</td><td>1238740.0</td><td>0001209191-17-023201</td><td>.txt</td><td>200.0</td><td>8827.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>10.0</td><td>0.0</td><td>null</td><td>US</td></tr><tr><td>108.91.91.hbc</td><td>2017-03-29</td><td>00:00:00</td><td>0.0</td><td>1238740.0</td><td>0001209191-17-023201</td><td>.txt</td><td>301.0</td><td>674.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>10.0</td><td>0.0</td><td>null</td><td>US</td></tr><tr><td>108.91.91.hbc</td><td>2017-03-29</td><td>00:00:00</td><td>0.0</td><td>1572427.0</td><td>0001209191-17-023203</td><td>.txt</td><td>301.0</td><td>674.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>10.0</td><td>0.0</td><td>null</td><td>US</td></tr><tr><td>115.111.104.igg</td><td>2017-03-29</td><td>00:00:00</td><td>0.0</td><td>84129.0</td><td>0001047469-16-012513</td><td>-index.htm</td><td>301.0</td><td>287.0</td><td>1.0</td><td>0.0</td><td>1.0</td><td>10.0</td><td>0.0</td><td>null</td><td>IN</td></tr><tr>< ...

# %%
# TEST - Run this cell to test your solution
dbTest("ET2-P-05-01-01", 249, countryLookupDF.count())
dbTest("ET2-P-05-01-02", 5000, logWithIPDF.count())

print("Tests passed!")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Tests passed!
# </div>

# %% [markdown]
# ### Step 2: Broadcast the Lookup Table
#
# Complete the following:<br><br>
#
# - Create a new DataFrame `logWithIPEnhancedDF`
# - Get the full country name by performing a broadcast join that broadcasts the lookup table to the server log
# - Drop all columns other than `EnglishShortName`

# %%
# TODO

from pyspark.sql.functions import broadcast

logWithIPEnhancedDF = (logWithIPDF
  .join(broadcast(countryLookupDF), logWithIPDF.IPLookupISO2 == countryLookupDF.alpha2Code)
  .drop("alpha2Code", "alpha3Code", "numericCode", "ISO31662SubdivisionCode", "independentTerritory")
)

display(logWithIPEnhancedDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ip</th><th>date</th><th>time</th><th>zone</th><th>cik</th><th>accession</th><th>extention</th><th>code</th><th>size</th><th>idx</th><th>norefer</th><th>noagent</th><th>find</th><th>crawler</th><th>browser</th><th>IPLookupISO2</th><th>EnglishShortName</th></tr></thead><tbody><tr><td>101.71.41.ihh</td><td>2017-03-29</td><td>00:00:00</td><td>0.0</td><td>1437491.0</td><td>0001245105-17-000052</td><td>xslF345X03/primary_doc.xml</td><td>301.0</td><td>687.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>10.0</td><td>0.0</td><td>null</td><td>CN</td><td>China</td></tr><tr><td>104.196.240.dda</td><td>2017-03-29</td><td>00:00:00</td><td>0.0</td><td>1270985.0</td><td>0001188112-04-001037</td><td>.txt</td><td>200.0</td><td>7619.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>10.0</td><td>0.0</td><td>null</td><td>US</td><td>United States of America</td></tr><tr><td>107.23.85.jfd</td><td>2017-03-29</td><td>00:00:00</td><td>0.0</td><td>1059376.0</td><td>0000905148-07-006108</td><td>-index.htm</td><td>200.0</td><td>2727.0</td><td>1.0</td><td>0.0</td><td>0.0</td><td>10.0</td><td>0.0</td><td>null</td><td>US</td><td>United States of America</td></tr><tr><td>107.23.85.jfd</td><td>2017-03-29</td><td>00:00:00</td><td>0.0</td><td>1059376.0</td><td>0000905148-08-001993</td><td>-index.htm</td><td>200.0</td><td>2710.0</td><td>1.0</td><td>0.0</td><td>0.0</td><td>10.0</td><td>0.0</td><td>null</td><td>US</td><td>United States of America</td></tr><tr><td>107.23.85.jfd</td><td>2017-03-29</td><td>00:00:00</td><td>0.0</td><td>1059376.0</td><td>0001104659-09-046963</td><td>-index.htm</td><td>200.0</td><td>2715.0</td><td>1.0</td><td>0.0</td><td>0.0</td><td>10.0</td><td>0.0</td><td>null</td><td>US</td><td>United States of America</td></tr><tr><td>107.23.85.jfd</td><td>2017-03-29</td><td>00:00:00</td><td>0.0</td><td>1364986.0</td><td>0000914121-06-002243</td><td>-index.htm</td><td>200.0</td><td>2786.0</td><td>1.0</td><td>0.0</td><td>0.0</td><td>10.0</td><td>0.0</td><td>null</td><td>US</td><td>United States of America</td></tr><tr><td>107.23.85.jfd</td><td>2017-03-29</td><td>00:00:00</td><td>0.0</td><td>1364986.0</td><td>0000914121-06-002251</td><td>-index.htm</td><td>200.0</td><td>2784.0</td><td>1.0</td><td>0.0</td><td>0.0</td><td>10.0</td><td>0.0</td><td>null</td><td>US</td><td>United States of America</td></tr><tr><td>108.240.248.gha</td><td>2017-03-29</td><td>00:00:00</td><td>0.0</td><td>1540159.0</td><td>0001217160-12-000029</td><td>f332scottlease.htm</td><td>200.0</td><td>49578.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>10.0</td><td>0.0</td><td>null</td><td>US</td><td>United States of America</td></tr><tr><td>108.59.8.fef</td><td>2017-03-29</td><td>00:00:00</td><td>0.0</td><td>732834.0</td><td>0001209191-15-017349</td><td>xslF345X03/doc4.xml</td><td>301.0</td><td>673.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>10.0</td><td>0.0</td><td>null</td><td>US</td><td>United States of America</td></tr><tr><td>108.91.91.hbc</td><td>2017-03-29</td><td>00:00:00</td><td>0.0</td><td>1629769.0</td><td>0001209191-17-023204</td><td>.txt</td><td>301.0</td><td>675.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>10.0</td><td>0.0</td><td>null</td><td>US</td><td>United States of America</td></tr><tr><td>108.91.91.hbc</td><td>2017-03-29</td><td>00:00:00</td><td>0.0</td><td>1238740.0</td><td>0001209191-17-023201</td><td>.txt</td><td>200.0</td><td>8827.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>10.0</td><td>0.0</td><td>null</td><td>US</td><td>United States of America</td></tr><tr><td>108.91.91.hbc</td><td>2017-03-29</td><td>00:00:00</td><td>0.0</td><td>1238740.0</td><td>0001209191-17-023201</td><td>.txt</td><td>301.0</td><td>674.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>10.0</td><td>0.0</td><td>null</td><td>US</td><td>United States of America</td></tr><tr><td>108.91.91.hbc</td><td>2017-03-29</td><td>00:00:00</td><td>0.0</td><td>1572427.0</td><td>0001209191-17-023 ...

# %%
# TEST - Run this cell to test your solution
cols = set(logWithIPEnhancedDF.columns)

dbTest("ET2-P-05-02-01", True, "EnglishShortName" in cols and "ip" in cols)
dbTest("ET2-P-05-02-02", True, "alpha2Code" not in cols and "ISO31662SubdivisionCode" not in cols)
dbTest("ET2-P-05-02-03", 5000, logWithIPEnhancedDF.count())

print("Tests passed!")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Tests passed!
# </div>

# %% [markdown]
# ## Review
# **Question:** Why are joins expensive operations?
# **Answer:** Joins perform a large number of row-wise comparisons, making the cost associated with joining tables grow with the size of the data in the tables.
#
# **Question:** What is the difference between a shuffle and broadcast join? How does Spark manage these differences?
# **Answer:** A shuffle join shuffles data between nodes in a cluster. By contrast, a broadcast join moves the smaller of two DataFrames to where the larger DataFrame sits, minimizing the overall data transfer. By default, Spark performs a broadcast join if the total number of records is below a certain threshold. The threshold can be manually specified or you can manually specify that a broadcast join should take place. Since the automatic determination of whether a shuffle join should take place is by number of records, this could mean that really wide data would take up significantly more space per record and should therefore be specified manually.
#
# **Question:** What is a lookup table?
# **Answer:** A lookup table is small table often used for referencing commonly used data such as mapping cities to countries.

# %% [markdown]
# ## ![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) Classroom-Cleanup<br>
#
# Run the **`Classroom-Cleanup`** cell below to remove any artifacts created by this lesson.

# %%
# %run "./Includes/Classroom-Cleanup"

# %% [markdown]
# ## Next Steps
#
# Start the next lesson, [Database Writes]($./ETL2 06 - Database Writes ).

# %% [markdown]
# ## Additional Topics & Resources
#
# **Q:** Where can I get more information on optimizing table joins where data skew is an issue?
# **A:** Check out the Databricks documentation on <a href="https://docs.databricks.com/spark/latest/spark-sql/skew-join.html" target="_blank">Skew Join Optimization</a>

# %% [markdown]
# -sandbox
# &copy; 2020 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the <a href="http://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/>
# <a href="https://databricks.com/privacy-policy">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use">Terms of Use</a> | <a href="http://help.databricks.com/">Support</a>
