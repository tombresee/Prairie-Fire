# %% [markdown]
# d-sandbox
#
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning" style="width: 600px; height: 163px">
# </div>

# %% [markdown]
# -sandbox
# <img src="https://files.training.databricks.com/images/Apache-Spark-Logo_TM_200px.png" style="float: left: margin: 20px"/>
#
# # Structured Streaming Concepts
#
# ## In this lesson you:
# * Stream data from a file and write it out to a distributed file system.
# * List active streams.
# * Stop active streams.
#
# ## Prerequisites
# * Web browser: **Chrome**
# * A cluster configured with **8 cores** and **DBR 6.3**
# * Suggested Courses from <a href="https://academy.databricks.com/" target="_blank">Databricks Academy</a>:
#   - ETL Part 1
#   - Spark-SQL
#
# ## Datasets Used
# Data from
# `/mnt/training/definitive-guide/data/activity-data-stream.json/`
# contains smartphone accelerometer samples from devices and users.
#
# The file consists of the following columns:
#
# | Field           | Description                  |
# |-----------------|------------------------------|
# | `Index`         | unique identifier of event   |
# | `x`             | acceleration in x-dir        |
# | `y`             | acceleration in y-dir        |
# | `z`             | acceleration in z-dir        |
# | `User`          | unique user identifier       |
# | `Model`         | i.e Nexus4                   |
# | `Device`        | type of Model                |
# | `gt`            | ground truth                 |
#
#
# <img alt="Side Note" title="Side Note" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.05em; transform:rotate(15deg)" src="https://files.training.databricks.com/static/images/icon-note.webp"/> The last column, **`gt`**, "ground truth" refers to what the person was ACTUALLY doing when the measurement was taken. In this case, walking, going up stairs, etc..

# %% [markdown]
# ## ![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) Classroom-Setup & Classroom-Cleanup<br>
#
# For each lesson to execute correctly, please make sure to run the **`Classroom-Setup`** cell at the start of each lesson (see the next cell) and the **`Classroom-Cleanup`** cell at the end of each lesson.

# %%
# %run "./Includes/Classroom-Setup"

# %% [markdown]
# <iframe
# src="//fast.wistia.net/embed/iframe/9649xyq1ae?videoFoam=true"
# style="border:1px solid #1cb1c2;"
# allowtransparency="true" scrolling="no" class="wistia_embed"
# name="wistia_embed" allowfullscreen mozallowfullscreen webkitallowfullscreen
# oallowfullscreen msallowfullscreen width="640" height="360" ></iframe>
# <div>
# <a target="_blank" href="https://fast.wistia.net/embed/iframe/9649xyq1ae?seo=false">
#   <img alt="Opens in new tab" src="https://files.training.databricks.com/static/images/external-link-icon-16x16.png"/>&nbsp;Watch full-screen.</a>
# </div>

# %% [markdown]
# <h2><img src="https://files.training.databricks.com/images/105/logo_spark_tiny.png"> Reading a Stream</h2>
#
# The method `SparkSession.readStream` returns a `DataStreamReader` used to configure the stream.
#
# There are a number of key points to the configuration of a `DataStreamReader`:
# * The schema
# * The type of stream: Files, Kafka, TCP/IP, etc
# * Configuration specific to the type of stream
#   * For files, the file type, the path to the files, max files, etc...
#   * For TCP/IP the server's address, port number, etc...
#   * For Kafka the server's address, port, topics, partitions, etc...

# %% [markdown]
# ### The Schema
#
# Every streaming DataFrame must have a schema - the definition of column names and data types.
#
# Some sources such as Kafka define the schema for you.
#
# In file-based streaming sources, for example, the schema is user-defined.

# %% [markdown]
# ### Why must a schema be specified for a streaming DataFrame?
#
# To say that another way...
#
# ### Why are streaming DataFrames unable to infer/read a schema?

# %% [markdown]
# -sandbox
#
# <script type="text/javascript">
#   window.onload = function() {
#     var allHints = document.getElementsByClassName("hint-1660");
#     var answer = document.getElementById("answer-1660");
#     var totalHints = allHints.length;
#     var nextHint = 0;
#     var hasAnswer = (answer != null);
#     var items = new Array();
#     var answerLabel = "Click here for the answer";
#     for (var i = 0; i < totalHints; i++) {
#       var elem = allHints[i];
#       var label = "";
#       if ((i + 1) == totalHints)
#         label = answerLabel;
#       else
#         label = "Click here for the next hint";
#       items.push({label: label, elem: elem});
#     }
#     if (hasAnswer) {
#       items.push({label: '', elem: answer});
#     }
#
#     var button = document.getElementById("hint-button-1660");
#     if (totalHints == 0) {
#       button.innerHTML = answerLabel;
#     }
#     button.onclick = function() {
#       items[nextHint].elem.style.display = 'block';
#       if ((nextHint + 1) >= items.length)
#         button.style.display = 'none';
#       else
#         button.innerHTML = items[nextHint].label;
#         nextHint += 1;
#     };
#     button.ondblclick = function(e) {
#       e.stopPropagation();
#     }
#     var answerCodeBlocks = document.getElementsByTagName("code");
#     for (var i = 0; i < answerCodeBlocks.length; i++) {
#       var elem = answerCodeBlocks[i];
#       var parent = elem.parentNode;
#       if (parent.name != "pre") {
#         var newNode = document.createElement("pre");
#         newNode.append(elem.cloneNode(true));
#         elem.replaceWith(newNode);
#         elem = newNode;
#       }
#       elem.ondblclick = function(e) {
#         e.stopPropagation();
#       };
#
#       elem.style.marginTop = "1em";
#     }
#   };
# </script>
#
# <div>
#   <button type="button" class="btn btn-light"
#           style="margin-top: 1em"
#           id="hint-button-1660">Click here for a hint</button>
# </div>
# <div id="answer-1660" style="padding-bottom: 20px; display: none">
#   The answer:
#   <div class="answer" style="margin-left: 1em">
# If you have enough data, you can infer the schema.
# &lt;br&gt;&lt;br&gt;
# If you don&#x27;t have enough data you run the risk of miss-inferring the schema.
# &lt;br&gt;&lt;br&gt;
# For example, you think you have all integers but the last value contains &quot;1.123&quot; (a float) or &quot;snoopy&quot; (a string).
# &lt;br&gt;&lt;br&gt;
# With a stream, we have to assume we don&#x27;t have enough data because we are starting with zero records.
# &lt;br&gt;&lt;br&gt;
# And unlike reading from a table or parquet file, there is nowhere from which to &quot;read&quot; the stream&#x27;s schema.
# &lt;br&gt;&lt;br&gt;
# For this reason, we must specify the schema manually.
#   </div>
# </div>

# %%
# Define the schema using a DDL-formatted string.
dataSchema = "Recorded_At timestamp, Device string, Index long, Model string, User string, _corrupt_record String, gt string, x double, y double, z double"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Configuring a File Stream
#
# In our example below, we will be consuming files written continuously to a pre-defined directory.
#
# To control how much data is pulled into Spark at once, we can specify the option `maxFilesPerTrigger`.
#
# In our example below, we will be reading in only one file for every trigger interval:
#
# `dsr.option("maxFilesPerTrigger", 1)`
#
# Both the location and file type are specified with the following call, which itself returns a `DataFrame`:
#
# `df = dsr.json(dataPath)`

# %%
dataPath = "dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json"
initialDF = (spark
  .readStream                            # Returns DataStreamReader
  .option("maxFilesPerTrigger", 1)       # Force processing of only 1 file per trigger 
  .schema(dataSchema)                    # Required for all streaming DataFrames
  .json(dataPath)                        # The stream's source directory and file type
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
type(initialDF)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[38]: pyspark.sql.dataframe.DataFrame</div>

# %%
initialDF
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[15]: DataFrame[Recorded_At: timestamp, Device: string, Index: bigint, Model: string, User: string, _corrupt_record: string, gt: string, x: double, y: double, z: double]</div>

# %%
initialDF.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[16]: [&#39;Recorded_At&#39;,
#  &#39;Device&#39;,
#  &#39;Index&#39;,
#  &#39;Model&#39;,
#  &#39;User&#39;,
#  &#39;_corrupt_record&#39;,
#  &#39;gt&#39;,
#  &#39;x&#39;,
#  &#39;y&#39;,
#  &#39;z&#39;]</div>

# %%
dir(initialDF)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[17]: [&#39;__class__&#39;,
#  &#39;__delattr__&#39;,
#  &#39;__dict__&#39;,
#  &#39;__dir__&#39;,
#  &#39;__doc__&#39;,
#  &#39;__eq__&#39;,
#  &#39;__format__&#39;,
#  &#39;__ge__&#39;,
#  &#39;__getattr__&#39;,
#  &#39;__getattribute__&#39;,
#  &#39;__getitem__&#39;,
#  &#39;__gt__&#39;,
#  &#39;__hash__&#39;,
#  &#39;__init__&#39;,
#  &#39;__init_subclass__&#39;,
#  &#39;__le__&#39;,
#  &#39;__lt__&#39;,
#  &#39;__module__&#39;,
#  &#39;__ne__&#39;,
#  &#39;__new__&#39;,
#  &#39;__reduce__&#39;,
#  &#39;__reduce_ex__&#39;,
#  &#39;__repr__&#39;,
#  &#39;__setattr__&#39;,
#  &#39;__sizeof__&#39;,
#  &#39;__str__&#39;,
# ...

# %%
"""
 'agg',
 'alias',
 'approxQuantile',
 'cache',
 'checkpoint',
 'coalesce',
 'colRegex',
 'collect',
 'columns',
 'corr',
 'count',
 'cov',
 'createGlobalTempView',
 'createOrReplaceGlobalTempView',
 'createOrReplaceTempView',
 'createTempView',
 'crossJoin',
 'crosstab',
 'cube',
 'describe',
 'distinct',
 'drop',
 'dropDuplicates',
 'drop_duplicates',
 'dropna',
 'dtypes',
 'exceptAll',
 'explain',
 'fillna',
 'filter',
 'first',
 'foreach',
 'foreachPartition',
 'freqItems',
 'groupBy',
 'groupby',
 'head',
 'hint',
 'intersect',
 'intersectAll',
 'isLocal',
 'isStreaming',
 'is_cached',
 'join',
 'limit',
 'localCheckpoint',
 'na',
 'orderBy',
 'persist',
 'printSchema',
 'randomSplit',
 'rdd',
 'registerTempTable',
 'repartition',
 'repartitionByRange',
 'replace',
 'rollup',
 'sample',
 'sampleBy',
 'schema',
 'select',
 'selectExpr',
 'show',
 'sort',
 'sortWithinPartitions',
 'sql_ctx',
 'stat',
 'storageLevel',
 'subtract',
 'summary',
 'take',
 'toDF',
 'toJSON',
 'toLocalIterator',
 'toPandas',
 'transform',
 'union',
 'unionAll',
 'unionByName',
 'unpersist',
 'where',
 'withColumn',
 'withColumnRenamed',
 'withWatermark',
 'write',
 'writeStream'] """
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# ...

# %%
initialDF.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[21]: [(&#39;Recorded_At&#39;, &#39;timestamp&#39;),
#  (&#39;Device&#39;, &#39;string&#39;),
#  (&#39;Index&#39;, &#39;bigint&#39;),
#  (&#39;Model&#39;, &#39;string&#39;),
#  (&#39;User&#39;, &#39;string&#39;),
#  (&#39;_corrupt_record&#39;, &#39;string&#39;),
#  (&#39;gt&#39;, &#39;string&#39;),
#  (&#39;x&#39;, &#39;double&#39;),
#  (&#39;y&#39;, &#39;double&#39;),
#  (&#39;z&#39;, &#39;double&#39;)]</div>

# %%
initialDF.schema
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[22]: StructType(List(StructField(Recorded_At,TimestampType,true),StructField(Device,StringType,true),StructField(Index,LongType,true),StructField(Model,StringType,true),StructField(User,StringType,true),StructField(_corrupt_record,StringType,true),StructField(gt,StringType,true),StructField(x,DoubleType,true),StructField(y,DoubleType,true),StructField(z,DoubleType,true)))</div>

# %%
#
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# And with the initial `DataFrame`, we can apply some transformations:

# %%
## transforming...

streamingDF = (initialDF
  .withColumnRenamed("Index", "User_ID")  # Pick a "better" column name
  .drop("_corrupt_record")                # Remove an unnecessary column
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
type(streamingDF)   #  ?
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[40]: pyspark.sql.dataframe.DataFrame</div>

# %%
streamingDF.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[27]: [&#39;Recorded_At&#39;, &#39;Device&#39;, &#39;User_ID&#39;, &#39;Model&#39;, &#39;User&#39;, &#39;gt&#39;, &#39;x&#39;, &#39;y&#39;, &#39;z&#39;]</div>

# %%
streamingDF
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[28]: DataFrame[Recorded_At: timestamp, Device: string, User_ID: bigint, Model: string, User: string, gt: string, x: double, y: double, z: double]</div>

# %%
#
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Streaming DataFrames
#
# Other than the call to `spark.readStream`, it looks just like any other `DataFrame`.
#
# But is it a "streaming" `DataFrame`?
#
# You can differentiate between a "static" and "streaming" `DataFrame` with the following call:

# %%
# Static vs Streaming?
streamingDF.isStreaming
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[36]: True</div>

# %%
type(streamingDF)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[41]: pyspark.sql.dataframe.DataFrame</div>

# %% [markdown]
# -sandbox
# ### Unsupported Operations
#
# Most operations on a "streaming" DataFrame are identical to a "static" DataFrame.
#
# There are some exceptions to this.
#
# Some operations that are not supported by streaming are
# * Sorting our never-ending stream by `Recorded_At`.
# * Aggregating our stream by some criterion.
#
# <img alt="Side Note" title="Side Note" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.05em; transform:rotate(15deg)" src="https://files.training.databricks.com/static/images/icon-note.webp"/> We will see in the following module how we can solve this problem.

# %%
streamingDF.show(1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">Py4JJavaError</span>                             Traceback (most recent call last)
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/utils.py</span> in <span class="ansi-cyan-fg">deco</span><span class="ansi-blue-fg">(*a, **kw)</span>
# <span class="ansi-green-intense-fg ansi-bold">     62</span>         <span class="ansi-green-fg">try</span><span class="ansi-blue-fg">:</span>
# ...

# %%
from pyspark.sql.functions import col

try:
  sortedDF = streamingDF.orderBy(col("Recorded_At").desc())
  display(sortedDF)
except:
  print("Sorting is not supported on an unaggregated stream")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Sorting is not supported on an unaggregated stream
# </div>

# %% [markdown]
# <iframe
# src="//fast.wistia.net/embed/iframe/agiu13vghf?videoFoam=true"
# style="border:1px solid #1cb1c2;"
# allowtransparency="true" scrolling="no" class="wistia_embed"
# name="wistia_embed" allowfullscreen mozallowfullscreen webkitallowfullscreen
# oallowfullscreen msallowfullscreen width="640" height="360" ></iframe>
# <div>
# <a target="_blank" href="https://fast.wistia.net/embed/iframe/agiu13vghf?seo=false">
#   <img alt="Opens in new tab" src="https://files.training.databricks.com/static/images/external-link-icon-16x16.png"/>&nbsp;Watch full-screen.</a>
# </div>

# %% [markdown]
# <h2><img src="https://files.training.databricks.com/images/105/logo_spark_tiny.png"> Writing a Stream</h2>
#
# The method `DataFrame.writeStream` returns a `DataStreamWriter` used to configure the output of the stream.
#
# There are a number of parameters to the `DataStreamWriter` configuration:
# * Query's name (optional) - This name must be unique among all the currently active queries in the associated SQLContext.
# * Trigger (optional) - Default value is `ProcessingTime(0`) and it will run the query as fast as possible.
# * Checkpointing directory (optional)
# * Output mode
# * Output sink
# * Configuration specific to the output sink, such as:
#   * The host, port and topic of the receiving Kafka server
#   * The file format and final destination of files
#   * A custom sink via `dsw.foreach(...)`
#
# Once the configuration is completed, we can trigger the job with a call to `dsw.start()`

# %% [markdown]
# ### Triggers
#
# The trigger specifies when the system should process the next set of data.
#
# | Trigger Type                           | Example | Notes |
# |----------------------------------------|-----------|-------------|
# | Unspecified                            |  | _DEFAULT_- The query will be executed as soon as the system has completed processing the previous query |
# | Fixed interval micro-batches           | `dsw.trigger(Trigger.ProcessingTime("6 hours"))` | The query will be executed in micro-batches and kicked off at the user-specified intervals |
# | One-time micro-batch                   | `dsw.trigger(Trigger.Once())` | The query will execute _only one_ micro-batch to process all the available data and then stop on its own |
# | Continuous w/fixed checkpoint interval | `dsw.trigger(Trigger.Continuous("1 second"))` | The query will be executed in a low-latency, continuous processing mode. _EXPERIMENTAL_ in 2.3.2 |
#
# In the example below, you will be using a fixed interval of 3 seconds:
#
# `dsw.trigger(Trigger.ProcessingTime("3 seconds"))`

# %% [markdown]
# ### Checkpointing
#
# A <b>checkpoint</b> stores the current state of your streaming job to a reliable storage system such as Azure Blob Storageor HDFS. It does not store the state of your streaming job to the local file system of any node in your cluster.
#
# Together with write ahead logs, a terminated stream can be restarted and it will continue from where it left off.
#
# To enable this feature, you only need to specify the location of a checkpoint directory:
#
# `dsw.option("checkpointLocation", checkpointPath)`

# %% [markdown]
# Points to consider:
# * If you do not have a checkpoint directory, when the streaming job stops, you lose all state around your streaming job and upon restart, you start from scratch.
# * For some sinks, you will get an error if you do not specify a checkpoint directory:<br/>
# `analysisException: 'checkpointLocation must be specified either through option("checkpointLocation", ...)..`
# * Also note that every streaming job should have its own checkpoint directory: no sharing.

# %% [markdown]
# ### Output Modes
#
# | Mode   | Example | Notes |
# | ------------- | ----------- |
# | **Complete** | `dsw.outputMode("complete")` | The entire updated Result Table is written to the sink. The individual sink implementation decides how to handle writing the entire table. |
# | **Append** | `dsw.outputMode("append")`     | Only the new rows appended to the Result Table since the last trigger are written to the sink. |
# | **Update** | `dsw.outputMode("update")`     | Only the rows in the Result Table that were updated since the last trigger will be outputted to the sink. Since Spark 2.1.1 |
#
# In the example below, we are writing to a Parquet directory which only supports the `append` mode:
#
# `dsw.outputMode("append")`

# %% [markdown]
# ### Output Sinks
#
# `DataStreamWriter.format` accepts the following values, among others:
#
# | Output Sink | Example                                          | Notes |
# | ----------- | ------------------------------------------------ | ----- |
# | **File**    | `dsw.format("parquet")`, `dsw.format("csv")`...  | Dumps the Result Table to a file. Supports Parquet, json, csv, etc.|
# | **Kafka**   | `dsw.format("kafka")`      | Writes the output to one or more topics in Kafka |
# | **Console** | `dsw.format("console")`    | Prints data to the console (useful for debugging) |
# | **Memory**  | `dsw.format("memory")`     | Updates an in-memory table, which can be queried through Spark SQL or the DataFrame API |
# | **foreach** | `dsw.foreach(writer: ForeachWriter)` | This is your "escape hatch", allowing you to write your own type of sink. |
# | **Delta**    | `dsw.format("delta")`     | A proprietary sink |
#
# In the example below, we will be appending files to a Parquet file and specifying its location with this call:
#
# `dsw.format("parquet").start(outputPathDir)`

# %% [markdown]
# <h2><img src="https://files.training.databricks.com/images/105/logo_spark_tiny.png"> Let's Do Some Streaming</h2>
#
# In the cell below, we write data from a streaming query to `outputPathDir`.
#
# There are a couple of things to note below:
# 0. We are giving the query a name via the call to `queryName` . We can use this later to reference the query by name.
# 0. Spark begins running jobs once we call `start`. This is equivalent to calling an action on a "static" DataFrame.
# 0. The call to `start` returns a `StreamingQuery` object. We can use this to interact with the running query.

# %%
outputPathDir = workingDir + "/output.parquet" # A subdirectory for our output
checkpointPath = workingDir + "/checkpoint"    # A subdirectory for our checkpoint & W-A logs
myStreamName = "lesson02_ps"                   # An arbitrary name for the stream
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
streamingQuery = (streamingDF                   # Start with our "streaming" DataFrame
  .writeStream                                  # Get the DataStreamWriter
  .queryName(myStreamName)                      # Name the query
  .trigger(processingTime="3 seconds")          # Configure for a 3-second micro-batch
  .format("parquet")                            # Specify the sink type, a Parquet file
  .option("checkpointLocation", checkpointPath) # Specify the location of checkpoint files & W-A logs
  .outputMode("append")                         # Write only new data to the "file"
  .start(outputPathDir)                         # Start the job, writing to the specified directory
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
"""
{
  "id" : "e3afeaa6-9bcf-4181-93f9-61693d055b39",
  "runId" : "4eca080d-ade2-40b7-9935-2149f3454993",
  "name" : "lesson02_ps",
  "timestamp" : "2020-04-05T14:31:03.757Z",
  "batchId" : 58,
  "numInputRows" : 76351,
  "inputRowsPerSecond" : 23377.526025719533,
  "processedRowsPerSecond" : 22696.492271105828,
  "durationMs" : {
    "addBatch" : 1875,
    "getBatch" : 66,
    "getOffset" : 539,
    "queryPlanning" : 11,
    "triggerExecution" : 3364,
    "walCommit" : 387
  },
  "stateOperators" : [ ],
  "sources" : [ {
    "description" : "FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]",
    "startOffset" : {
      "logOffset" : 57
    },
    "endOffset" : {
      "logOffset" : 58
    },
    "numInputRows" : 76351,
    "inputRowsPerSecond" : 23377.526025719533,
    "processedRowsPerSecond" : 22696.492271105828
  } ],
  "sink" : {
    "description" : "FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]"
  }
}"""
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# ...

# %%
type(streamingQuery)  #  !!!!!!!!!!!!!!!!!!!
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[45]: pyspark.sql.streaming.StreamingQuery</div>

# %%
for method in dir(streamingQuery):
  if not method.startswith("_"):
    print(method)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">awaitTermination
# exception
# explain
# id
# isActive
# lastProgress
# name
# processAllAvailable
# recentProgress
# runId
# status
# stop
# </div>

# %%
streamingQuery.status
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[47]: {&#39;message&#39;: &#39;Processing new data&#39;,
#  &#39;isDataAvailable&#39;: True,
#  &#39;isTriggerActive&#39;: True}</div>

# %%
streamingQuery.id
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[48]: &#39;e3afeaa6-9bcf-4181-93f9-61693d055b39&#39;</div>

# %%
streamingQuery.isActive
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[49]: True</div>

# %%
streamingQuery.lastProgress
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[50]: {&#39;id&#39;: &#39;e3afeaa6-9bcf-4181-93f9-61693d055b39&#39;,
#  &#39;runId&#39;: &#39;4eca080d-ade2-40b7-9935-2149f3454993&#39;,
#  &#39;name&#39;: &#39;lesson02_ps&#39;,
#  &#39;timestamp&#39;: &#39;2020-04-05T14:28:56.240Z&#39;,
#  &#39;batchId&#39;: 21,
#  &#39;numInputRows&#39;: 87396,
#  &#39;inputRowsPerSecond&#39;: 22962.69048870205,
#  &#39;processedRowsPerSecond&#39;: 25128.234617596318,
#  &#39;durationMs&#39;: {&#39;addBatch&#39;: 2165,
#   &#39;getBatch&#39;: 58,
#   &#39;getOffset&#39;: 446,
#   &#39;queryPlanning&#39;: 13,
#   &#39;triggerExecution&#39;: 3478,
#   &#39;walCommit&#39;: 408},
# ...

# %%
streamingQuery.name
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[51]: &#39;lesson02_ps&#39;</div>

# %%
streamingQuery.runId
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[52]: &#39;4eca080d-ade2-40b7-9935-2149f3454993&#39;</div>

# %%
streamingQuery
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[54]: &lt;pyspark.sql.streaming.StreamingQuery at 0x7f56f8d422e8&gt;</div>

# %%
# Wait until stream is done initializing...
# This method will be explained shortly.
untilStreamIsReady(myStreamName)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The stream lesson02_ps is active and ready.
# </div>

# %% [markdown]
# <h2><img src="https://files.training.databricks.com/images/105/logo_spark_tiny.png"> Managing Streaming Queries</h2>
#
# When a query is started, the `StreamingQuery` object can be used to monitor and manage the query.
#
# | Method    |  Description |
# | ----------- | ------------------------------- |
# |`id`| get unique identifier of the running query that persists across restarts from checkpoint data |
# |`runId`| get unique id of this run of the query, which will be generated at every start/restart |
# |`name`| get name of the auto-generated or user-specified name |
# |`explain()`| print detailed explanations of the query |
# |`stop()`| stop query |
# |`awaitTermination()`| block until query is terminated, with stop() or with error |
# |`exception`| exception if query terminated with error |
# |`recentProgress`| array of most recent progress updates for this query |
# |`lastProgress`| most recent progress update of this streaming query |

# %%
streamingQuery.recentProgress
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[57]: [{&#39;id&#39;: &#39;e3afeaa6-9bcf-4181-93f9-61693d055b39&#39;,
#   &#39;runId&#39;: &#39;4eca080d-ade2-40b7-9935-2149f3454993&#39;,
#   &#39;name&#39;: &#39;lesson02_ps&#39;,
#   &#39;timestamp&#39;: &#39;2020-04-05T14:27:27.648Z&#39;,
#   &#39;batchId&#39;: 0,
#   &#39;numInputRows&#39;: 80096,
#   &#39;processedRowsPerSecond&#39;: 7459.811865511781,
#   &#39;durationMs&#39;: {&#39;addBatch&#39;: 8723,
#    &#39;getBatch&#39;: 116,
#    &#39;getOffset&#39;: 780,
#    &#39;queryPlanning&#39;: 95,
#    &#39;triggerExecution&#39;: 10727,
#    &#39;walCommit&#39;: 393},
#   &#39;stateOperators&#39;: [],
# ...

# %%
"""
Out[57]: [{'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:27:27.648Z',
  'batchId': 0,
  'numInputRows': 80096,
  'processedRowsPerSecond': 7459.811865511781,
  'durationMs': {'addBatch': 8723,
   'getBatch': 116,
   'getOffset': 780,
   'queryPlanning': 95,
   'triggerExecution': 10727,
   'walCommit': 393},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': None,
    'endOffset': {'logOffset': 0},
    'numInputRows': 80096,
    'processedRowsPerSecond': 7459.811865511781}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:27:38.438Z',
  'batchId': 1,
  'numInputRows': 68545,
  'inputRowsPerSecond': 6352.641334569046,
  'processedRowsPerSecond': 14460.97046413502,
  'durationMs': {'addBatch': 3149,
   'getBatch': 71,
   'getOffset': 568,
   'queryPlanning': 21,
   'triggerExecution': 4740,
   'walCommit': 485},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 0},
    'endOffset': {'logOffset': 1},
    'numInputRows': 68545,
    'inputRowsPerSecond': 6352.641334569046,
    'processedRowsPerSecond': 14460.97046413502}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:27:43.179Z',
  'batchId': 2,
  'numInputRows': 71211,
  'inputRowsPerSecond': 15020.248892638685,
  'processedRowsPerSecond': 16438.36565096953,
  'durationMs': {'addBatch': 2772,
   'getBatch': 76,
   'getOffset': 582,
   'queryPlanning': 35,
   'triggerExecution': 4332,
   'walCommit': 465},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 1},
    'endOffset': {'logOffset': 2},
    'numInputRows': 71211,
    'inputRowsPerSecond': 15020.248892638685,
    'processedRowsPerSecond': 16438.36565096953}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:27:47.516Z',
  'batchId': 3,
  'numInputRows': 81992,
  'inputRowsPerSecond': 18905.234032741526,
  'processedRowsPerSecond': 19179.41520467836,
  'durationMs': {'addBatch': 2758,
   'getBatch': 99,
   'getOffset': 583,
   'queryPlanning': 40,
   'triggerExecution': 4274,
   'walCommit': 369},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 2},
    'endOffset': {'logOffset': 3},
    'numInputRows': 81992,
    'inputRowsPerSecond': 18905.234032741526,
    'processedRowsPerSecond': 19179.41520467836}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:27:51.792Z',
  'batchId': 4,
  'numInputRows': 73878,
  'inputRowsPerSecond': 17277.36202057998,
  'processedRowsPerSecond': 19539.27532398836,
  'durationMs': {'addBatch': 2342,
   'getBatch': 92,
   'getOffset': 544,
   'queryPlanning': 20,
   'triggerExecution': 3780,
   'walCommit': 354},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 3},
    'endOffset': {'logOffset': 4},
    'numInputRows': 73878,
    'inputRowsPerSecond': 17277.36202057998,
    'processedRowsPerSecond': 19539.27532398836}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:27:55.574Z',
  'batchId': 5,
  'numInputRows': 74940,
  'inputRowsPerSecond': 19814.912744579586,
  'processedRowsPerSecond': 18735.0,
  'durationMs': {'addBatch': 2477,
   'getBatch': 107,
   'getOffset': 520,
   'queryPlanning': 36,
   'triggerExecution': 4000,
   'walCommit': 446},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 4},
    'endOffset': {'logOffset': 5},
    'numInputRows': 74940,
    'inputRowsPerSecond': 19814.912744579586,
    'processedRowsPerSecond': 18735.0}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:27:59.575Z',
  'batchId': 6,
  'numInputRows': 85065,
  'inputRowsPerSecond': 21260.934766308423,
  'processedRowsPerSecond': 22492.067689053412,
  'durationMs': {'addBatch': 2313,
   'getBatch': 70,
   'getOffset': 578,
   'queryPlanning': 30,
   'triggerExecution': 3782,
   'walCommit': 396},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 5},
    'endOffset': {'logOffset': 6},
    'numInputRows': 85065,
    'inputRowsPerSecond': 21260.934766308423,
    'processedRowsPerSecond': 22492.067689053412}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:28:03.359Z',
  'batchId': 7,
  'numInputRows': 73450,
  'inputRowsPerSecond': 19410.676532769558,
  'processedRowsPerSecond': 19354.413702239788,
  'durationMs': {'addBatch': 2232,
   'getBatch': 116,
   'getOffset': 498,
   'queryPlanning': 39,
   'triggerExecution': 3795,
   'walCommit': 405},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 6},
    'endOffset': {'logOffset': 7},
    'numInputRows': 73450,
    'inputRowsPerSecond': 19410.676532769558,
    'processedRowsPerSecond': 19354.413702239788}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:28:07.155Z',
  'batchId': 8,
  'numInputRows': 72852,
  'inputRowsPerSecond': 19191.780821917808,
  'processedRowsPerSecond': 18117.881124098483,
  'durationMs': {'addBatch': 2512,
   'getBatch': 75,
   'getOffset': 656,
   'queryPlanning': 31,
   'triggerExecution': 4021,
   'walCommit': 373},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 7},
    'endOffset': {'logOffset': 8},
    'numInputRows': 72852,
    'inputRowsPerSecond': 19191.780821917808,
    'processedRowsPerSecond': 18117.881124098483}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:28:11.178Z',
  'batchId': 9,
  'numInputRows': 84617,
  'inputRowsPerSecond': 21033.308476261496,
  'processedRowsPerSecond': 16111.386138613861,
  'durationMs': {'addBatch': 2976,
   'getBatch': 139,
   'getOffset': 1237,
   'queryPlanning': 31,
   'triggerExecution': 5252,
   'walCommit': 382},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 8},
    'endOffset': {'logOffset': 9},
    'numInputRows': 84617,
    'inputRowsPerSecond': 21033.308476261496,
    'processedRowsPerSecond': 16111.386138613861}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:28:16.432Z',
  'batchId': 10,
  'numInputRows': 83899,
  'inputRowsPerSecond': 15968.5953559193,
  'processedRowsPerSecond': 21380.98878695209,
  'durationMs': {'addBatch': 2208,
   'getBatch': 83,
   'getOffset': 566,
   'queryPlanning': 33,
   'triggerExecution': 3924,
   'walCommit': 654},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 9},
    'endOffset': {'logOffset': 10},
    'numInputRows': 83899,
    'inputRowsPerSecond': 15968.5953559193,
    'processedRowsPerSecond': 21380.98878695209}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:28:20.357Z',
  'batchId': 11,
  'numInputRows': 87564,
  'inputRowsPerSecond': 22309.299363057326,
  'processedRowsPerSecond': 24235.815112095213,
  'durationMs': {'addBatch': 2129,
   'getBatch': 68,
   'getOffset': 546,
   'queryPlanning': 14,
   'triggerExecution': 3613,
   'walCommit': 468},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 10},
    'endOffset': {'logOffset': 11},
    'numInputRows': 87564,
    'inputRowsPerSecond': 22309.299363057326,
    'processedRowsPerSecond': 24235.815112095213}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:28:23.971Z',
  'batchId': 12,
  'numInputRows': 75758,
  'inputRowsPerSecond': 20962.368566685112,
  'processedRowsPerSecond': 22540.315382326688,
  'durationMs': {'addBatch': 1947,
   'getBatch': 66,
   'getOffset': 549,
   'queryPlanning': 26,
   'triggerExecution': 3361,
   'walCommit': 392},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 11},
    'endOffset': {'logOffset': 12},
    'numInputRows': 75758,
    'inputRowsPerSecond': 20962.368566685112,
    'processedRowsPerSecond': 22540.315382326688}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:28:27.334Z',
  'batchId': 13,
  'numInputRows': 85739,
  'inputRowsPerSecond': 25494.79631281594,
  'processedRowsPerSecond': 23717.56569847856,
  'durationMs': {'addBatch': 2142,
   'getBatch': 108,
   'getOffset': 534,
   'queryPlanning': 42,
   'triggerExecution': 3615,
   'walCommit': 463},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 12},
    'endOffset': {'logOffset': 13},
    'numInputRows': 85739,
    'inputRowsPerSecond': 25494.79631281594,
    'processedRowsPerSecond': 23717.56569847856}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:28:30.951Z',
  'batchId': 14,
  'numInputRows': 71860,
  'inputRowsPerSecond': 19867.29333701963,
  'processedRowsPerSecond': 19730.91707852828,
  'durationMs': {'addBatch': 2303,
   'getBatch': 70,
   'getOffset': 566,
   'queryPlanning': 23,
   'triggerExecution': 3642,
   'walCommit': 348},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 13},
    'endOffset': {'logOffset': 14},
    'numInputRows': 71860,
    'inputRowsPerSecond': 19867.29333701963,
    'processedRowsPerSecond': 19730.91707852828}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:28:34.594Z',
  'batchId': 15,
  'numInputRows': 77935,
  'inputRowsPerSecond': 21393.082624210816,
  'processedRowsPerSecond': 21346.206518761985,
  'durationMs': {'addBatch': 2000,
   'getBatch': 69,
   'getOffset': 564,
   'queryPlanning': 49,
   'triggerExecution': 3651,
   'walCommit': 421},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 14},
    'endOffset': {'logOffset': 15},
    'numInputRows': 77935,
    'inputRowsPerSecond': 21393.082624210816,
    'processedRowsPerSecond': 21346.206518761985}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:28:38.249Z',
  'batchId': 16,
  'numInputRows': 80692,
  'inputRowsPerSecond': 22077.154582763338,
  'processedRowsPerSecond': 23594.152046783627,
  'durationMs': {'addBatch': 2011,
   'getBatch': 67,
   'getOffset': 635,
   'queryPlanning': 20,
   'triggerExecution': 3420,
   'walCommit': 326},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 15},
    'endOffset': {'logOffset': 16},
    'numInputRows': 80692,
    'inputRowsPerSecond': 22077.154582763338,
    'processedRowsPerSecond': 23594.152046783627}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:28:41.670Z',
  'batchId': 17,
  'numInputRows': 76864,
  'inputRowsPerSecond': 22468.284127448114,
  'processedRowsPerSecond': 24080.20050125313,
  'durationMs': {'addBatch': 1889,
   'getBatch': 65,
   'getOffset': 490,
   'queryPlanning': 13,
   'triggerExecution': 3192,
   'walCommit': 386},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 16},
    'endOffset': {'logOffset': 17},
    'numInputRows': 76864,
    'inputRowsPerSecond': 22468.284127448114,
    'processedRowsPerSecond': 24080.20050125313}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:28:44.863Z',
  'batchId': 18,
  'numInputRows': 72742,
  'inputRowsPerSecond': 22781.709990604446,
  'processedRowsPerSecond': 23881.155613919895,
  'durationMs': {'addBatch': 1705,
   'getBatch': 103,
   'getOffset': 458,
   'queryPlanning': 26,
   'triggerExecution': 3046,
   'walCommit': 355},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 17},
    'endOffset': {'logOffset': 18},
    'numInputRows': 72742,
    'inputRowsPerSecond': 22781.709990604446,
    'processedRowsPerSecond': 23881.155613919895}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:28:47.910Z',
  'batchId': 19,
  'numInputRows': 77088,
  'inputRowsPerSecond': 25299.638989169674,
  'processedRowsPerSecond': 17043.555162502766,
  'durationMs': {'addBatch': 2589,
   'getBatch': 67,
   'getOffset': 1149,
   'queryPlanning': 17,
   'triggerExecution': 4523,
   'walCommit': 328},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 18},
    'endOffset': {'logOffset': 19},
    'numInputRows': 77088,
    'inputRowsPerSecond': 25299.638989169674,
    'processedRowsPerSecond': 17043.555162502766}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:28:52.434Z',
  'batchId': 20,
  'numInputRows': 73906,
  'inputRowsPerSecond': 16336.427939876216,
  'processedRowsPerSecond': 19423.390275952694,
  'durationMs': {'addBatch': 2387,
   'getBatch': 102,
   'getOffset': 562,
   'queryPlanning': 25,
   'triggerExecution': 3805,
   'walCommit': 331},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 19},
    'endOffset': {'logOffset': 20},
    'numInputRows': 73906,
    'inputRowsPerSecond': 16336.427939876216,
    'processedRowsPerSecond': 19423.390275952694}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:28:56.240Z',
  'batchId': 21,
  'numInputRows': 87396,
  'inputRowsPerSecond': 22962.69048870205,
  'processedRowsPerSecond': 25128.234617596318,
  'durationMs': {'addBatch': 2165,
   'getBatch': 58,
   'getOffset': 446,
   'queryPlanning': 13,
   'triggerExecution': 3478,
   'walCommit': 408},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 20},
    'endOffset': {'logOffset': 21},
    'numInputRows': 87396,
    'inputRowsPerSecond': 22962.69048870205,
    'processedRowsPerSecond': 25128.234617596318}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:28:59.719Z',
  'batchId': 22,
  'numInputRows': 73577,
  'inputRowsPerSecond': 21148.893360160964,
  'processedRowsPerSecond': 20108.499590051928,
  'durationMs': {'addBatch': 1986,
   'getBatch': 99,
   'getOffset': 702,
   'queryPlanning': 12,
   'triggerExecution': 3659,
   'walCommit': 359},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 21},
    'endOffset': {'logOffset': 22},
    'numInputRows': 73577,
    'inputRowsPerSecond': 21148.893360160964,
    'processedRowsPerSecond': 20108.499590051928}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:29:03.380Z',
  'batchId': 23,
  'numInputRows': 72463,
  'inputRowsPerSecond': 19793.225894564326,
  'processedRowsPerSecond': 20900.77877127199,
  'durationMs': {'addBatch': 1762,
   'getBatch': 54,
   'getOffset': 594,
   'queryPlanning': 12,
   'triggerExecution': 3467,
   'walCommit': 581},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 22},
    'endOffset': {'logOffset': 23},
    'numInputRows': 72463,
    'inputRowsPerSecond': 19793.225894564326,
    'processedRowsPerSecond': 20900.77877127199}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:29:06.848Z',
  'batchId': 24,
  'numInputRows': 78601,
  'inputRowsPerSecond': 22664.648212226068,
  'processedRowsPerSecond': 23186.13569321534,
  'durationMs': {'addBatch': 1945,
   'getBatch': 107,
   'getOffset': 514,
   'queryPlanning': 14,
   'triggerExecution': 3390,
   'walCommit': 395},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 23},
    'endOffset': {'logOffset': 24},
    'numInputRows': 78601,
    'inputRowsPerSecond': 22664.648212226068,
    'processedRowsPerSecond': 23186.13569321534}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:29:10.240Z',
  'batchId': 25,
  'numInputRows': 82256,
  'inputRowsPerSecond': 24250.0,
  'processedRowsPerSecond': 21510.460251046024,
  'durationMs': {'addBatch': 2256,
   'getBatch': 111,
   'getOffset': 539,
   'queryPlanning': 10,
   'triggerExecution': 3824,
   'walCommit': 372},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 24},
    'endOffset': {'logOffset': 25},
    'numInputRows': 82256,
    'inputRowsPerSecond': 24250.0,
    'processedRowsPerSecond': 21510.460251046024}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:29:14.066Z',
  'batchId': 26,
  'numInputRows': 81809,
  'inputRowsPerSecond': 21382.38369053842,
  'processedRowsPerSecond': 21216.026970954357,
  'durationMs': {'addBatch': 2479,
   'getBatch': 57,
   'getOffset': 457,
   'queryPlanning': 10,
   'triggerExecution': 3856,
   'walCommit': 478},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 25},
    'endOffset': {'logOffset': 26},
    'numInputRows': 81809,
    'inputRowsPerSecond': 21382.38369053842,
    'processedRowsPerSecond': 21216.026970954357}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',

*** WARNING: skipped 32002 bytes of output ***

   'walCommit': 383},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 60},
    'endOffset': {'logOffset': 61},
    'numInputRows': 79444,
    'inputRowsPerSecond': 23799.880167765128,
    'processedRowsPerSecond': 26375.830013280214}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:31:18.503Z',
  'batchId': 62,
  'numInputRows': 81506,
  'inputRowsPerSecond': 27051.443743776967,
  'processedRowsPerSecond': 27489.3760539629,
  'durationMs': {'addBatch': 1679,
   'getBatch': 62,
   'getOffset': 517,
   'queryPlanning': 8,
   'triggerExecution': 2965,
   'walCommit': 356},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 61},
    'endOffset': {'logOffset': 62},
    'numInputRows': 81506,
    'inputRowsPerSecond': 27051.443743776967,
    'processedRowsPerSecond': 27489.3760539629}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:31:21.471Z',
  'batchId': 63,
  'numInputRows': 85500,
  'inputRowsPerSecond': 28807.277628032345,
  'processedRowsPerSecond': 25924.80291085506,
  'durationMs': {'addBatch': 1960,
   'getBatch': 50,
   'getOffset': 520,
   'queryPlanning': 12,
   'triggerExecution': 3298,
   'walCommit': 350},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 62},
    'endOffset': {'logOffset': 63},
    'numInputRows': 85500,
    'inputRowsPerSecond': 28807.277628032345,
    'processedRowsPerSecond': 25924.80291085506}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:31:24.770Z',
  'batchId': 64,
  'numInputRows': 74752,
  'inputRowsPerSecond': 22658.987571991514,
  'processedRowsPerSecond': 22783.297775068575,
  'durationMs': {'addBatch': 1978,
   'getBatch': 83,
   'getOffset': 458,
   'queryPlanning': 28,
   'triggerExecution': 3281,
   'walCommit': 348},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 63},
    'endOffset': {'logOffset': 64},
    'numInputRows': 74752,
    'inputRowsPerSecond': 22658.987571991514,
    'processedRowsPerSecond': 22783.297775068575}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:31:28.055Z',
  'batchId': 65,
  'numInputRows': 82343,
  'inputRowsPerSecond': 25066.36225266362,
  'processedRowsPerSecond': 23359.71631205674,
  'durationMs': {'addBatch': 2217,
   'getBatch': 76,
   'getOffset': 445,
   'queryPlanning': 10,
   'triggerExecution': 3525,
   'walCommit': 384},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 64},
    'endOffset': {'logOffset': 65},
    'numInputRows': 82343,
    'inputRowsPerSecond': 25066.36225266362,
    'processedRowsPerSecond': 23359.71631205674}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:31:31.581Z',
  'batchId': 66,
  'numInputRows': 76876,
  'inputRowsPerSecond': 21802.609188882587,
  'processedRowsPerSecond': 19686.555697823303,
  'durationMs': {'addBatch': 2727,
   'getBatch': 55,
   'getOffset': 439,
   'queryPlanning': 9,
   'triggerExecution': 3905,
   'walCommit': 362},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 65},
    'endOffset': {'logOffset': 66},
    'numInputRows': 76876,
    'inputRowsPerSecond': 21802.609188882587,
    'processedRowsPerSecond': 19686.555697823303}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:31:35.486Z',
  'batchId': 67,
  'numInputRows': 79966,
  'inputRowsPerSecond': 20477.84891165173,
  'processedRowsPerSecond': 25377.97524595367,
  'durationMs': {'addBatch': 1953,
   'getBatch': 63,
   'getOffset': 430,
   'queryPlanning': 14,
   'triggerExecution': 3151,
   'walCommit': 350},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 66},
    'endOffset': {'logOffset': 67},
    'numInputRows': 79966,
    'inputRowsPerSecond': 20477.84891165173,
    'processedRowsPerSecond': 25377.97524595367}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:31:38.637Z',
  'batchId': 68,
  'numInputRows': 71593,
  'inputRowsPerSecond': 22720.723579815934,
  'processedRowsPerSecond': 21212.74074074074,
  'durationMs': {'addBatch': 1874,
   'getBatch': 65,
   'getOffset': 473,
   'queryPlanning': 7,
   'triggerExecution': 3375,
   'walCommit': 644},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 67},
    'endOffset': {'logOffset': 68},
    'numInputRows': 71593,
    'inputRowsPerSecond': 22720.723579815934,
    'processedRowsPerSecond': 21212.74074074074}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:31:42.013Z',
  'batchId': 69,
  'numInputRows': 76554,
  'inputRowsPerSecond': 22675.94786729858,
  'processedRowsPerSecond': 17757.828810020877,
  'durationMs': {'addBatch': 2355,
   'getBatch': 57,
   'getOffset': 1034,
   'queryPlanning': 10,
   'triggerExecution': 4310,
   'walCommit': 422},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 68},
    'endOffset': {'logOffset': 69},
    'numInputRows': 76554,
    'inputRowsPerSecond': 22675.94786729858,
    'processedRowsPerSecond': 17757.828810020877}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:31:46.324Z',
  'batchId': 70,
  'numInputRows': 80823,
  'inputRowsPerSecond': 18748.086290883784,
  'processedRowsPerSecond': 25069.168734491315,
  'durationMs': {'addBatch': 1950,
   'getBatch': 65,
   'getOffset': 438,
   'queryPlanning': 8,
   'triggerExecution': 3224,
   'walCommit': 358},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 69},
    'endOffset': {'logOffset': 70},
    'numInputRows': 80823,
    'inputRowsPerSecond': 18748.086290883784,
    'processedRowsPerSecond': 25069.168734491315}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:31:49.549Z',
  'batchId': 71,
  'numInputRows': 80497,
  'inputRowsPerSecond': 24960.310077519378,
  'processedRowsPerSecond': 26886.105544422175,
  'durationMs': {'addBatch': 1821,
   'getBatch': 90,
   'getOffset': 391,
   'queryPlanning': 11,
   'triggerExecution': 2994,
   'walCommit': 320},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 70},
    'endOffset': {'logOffset': 71},
    'numInputRows': 80497,
    'inputRowsPerSecond': 24960.310077519378,
    'processedRowsPerSecond': 26886.105544422175}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:31:52.543Z',
  'batchId': 72,
  'numInputRows': 79063,
  'inputRowsPerSecond': 26407.147628590512,
  'processedRowsPerSecond': 24538.48541278709,
  'durationMs': {'addBatch': 2057,
   'getBatch': 54,
   'getOffset': 400,
   'queryPlanning': 10,
   'triggerExecution': 3222,
   'walCommit': 364},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 71},
    'endOffset': {'logOffset': 72},
    'numInputRows': 79063,
    'inputRowsPerSecond': 26407.147628590512,
    'processedRowsPerSecond': 24538.48541278709}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:31:55.765Z',
  'batchId': 73,
  'numInputRows': 83745,
  'inputRowsPerSecond': 25991.620111731845,
  'processedRowsPerSecond': 28709.29036681522,
  'durationMs': {'addBatch': 1768,
   'getBatch': 61,
   'getOffset': 435,
   'queryPlanning': 12,
   'triggerExecution': 2917,
   'walCommit': 313},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 72},
    'endOffset': {'logOffset': 73},
    'numInputRows': 83745,
    'inputRowsPerSecond': 25991.620111731845,
    'processedRowsPerSecond': 28709.29036681522}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:31:58.682Z',
  'batchId': 74,
  'numInputRows': 78478,
  'inputRowsPerSecond': 26903.668152211176,
  'processedRowsPerSecond': 26793.444861727552,
  'durationMs': {'addBatch': 1772,
   'getBatch': 65,
   'getOffset': 429,
   'queryPlanning': 7,
   'triggerExecution': 2929,
   'walCommit': 338},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 73},
    'endOffset': {'logOffset': 74},
    'numInputRows': 78478,
    'inputRowsPerSecond': 26903.668152211176,
    'processedRowsPerSecond': 26793.444861727552}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:32:01.611Z',
  'batchId': 75,
  'numInputRows': 74686,
  'inputRowsPerSecond': 25498.805052919088,
  'processedRowsPerSecond': 18898.27935222672,
  'durationMs': {'addBatch': 2674,
   'getBatch': 67,
   'getOffset': 440,
   'queryPlanning': 23,
   'triggerExecution': 3952,
   'walCommit': 378},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 74},
    'endOffset': {'logOffset': 75},
    'numInputRows': 74686,
    'inputRowsPerSecond': 25498.805052919088,
    'processedRowsPerSecond': 18898.27935222672}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:32:05.563Z',
  'batchId': 76,
  'numInputRows': 78489,
  'inputRowsPerSecond': 19860.576923076922,
  'processedRowsPerSecond': 25012.42829827916,
  'durationMs': {'addBatch': 1781,
   'getBatch': 81,
   'getOffset': 478,
   'queryPlanning': 11,
   'triggerExecution': 3138,
   'walCommit': 387},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 75},
    'endOffset': {'logOffset': 76},
    'numInputRows': 78489,
    'inputRowsPerSecond': 19860.576923076922,
    'processedRowsPerSecond': 25012.42829827916}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:32:08.702Z',
  'batchId': 77,
  'numInputRows': 81290,
  'inputRowsPerSecond': 25896.78241478178,
  'processedRowsPerSecond': 23748.174116272276,
  'durationMs': {'addBatch': 2134,
   'getBatch': 62,
   'getOffset': 445,
   'queryPlanning': 9,
   'triggerExecution': 3423,
   'walCommit': 390},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 76},
    'endOffset': {'logOffset': 77},
    'numInputRows': 81290,
    'inputRowsPerSecond': 25896.78241478178,
    'processedRowsPerSecond': 23748.174116272276}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:32:12.126Z',
  'batchId': 78,
  'numInputRows': 71029,
  'inputRowsPerSecond': 20744.45093457944,
  'processedRowsPerSecond': 24577.50865051903,
  'durationMs': {'addBatch': 1650,
   'getBatch': 108,
   'getOffset': 443,
   'queryPlanning': 9,
   'triggerExecution': 2890,
   'walCommit': 307},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 77},
    'endOffset': {'logOffset': 78},
    'numInputRows': 71029,
    'inputRowsPerSecond': 20744.45093457944,
    'processedRowsPerSecond': 24577.50865051903}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:32:15.017Z',
  'batchId': 79,
  'numInputRows': 76077,
  'inputRowsPerSecond': 26315.115876859218,
  'processedRowsPerSecond': 18349.493487698986,
  'durationMs': {'addBatch': 2407,
   'getBatch': 142,
   'getOffset': 919,
   'queryPlanning': 12,
   'triggerExecution': 4146,
   'walCommit': 319},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 78},
    'endOffset': {'logOffset': 79},
    'numInputRows': 76077,
    'inputRowsPerSecond': 26315.115876859218,
    'processedRowsPerSecond': 18349.493487698986}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:32:19.163Z',
  'batchId': 80,
  'numInputRows': 0,
  'inputRowsPerSecond': 0.0,
  'processedRowsPerSecond': 0.0,
  'durationMs': {'getOffset': 70, 'triggerExecution': 71},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 79},
    'endOffset': {'logOffset': 79},
    'numInputRows': 0,
    'inputRowsPerSecond': 0.0,
    'processedRowsPerSecond': 0.0}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:32:30.000Z',
  'batchId': 80,
  'numInputRows': 0,
  'inputRowsPerSecond': 0.0,
  'processedRowsPerSecond': 0.0,
  'durationMs': {'getOffset': 70, 'triggerExecution': 71},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 79},
    'endOffset': {'logOffset': 79},
    'numInputRows': 0,
    'inputRowsPerSecond': 0.0,
    'processedRowsPerSecond': 0.0}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:32:39.001Z',
  'batchId': 80,
  'numInputRows': 0,
  'inputRowsPerSecond': 0.0,
  'processedRowsPerSecond': 0.0,
  'durationMs': {'getOffset': 1376, 'triggerExecution': 1376},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 79},
    'endOffset': {'logOffset': 79},
    'numInputRows': 0,
    'inputRowsPerSecond': 0.0,
    'processedRowsPerSecond': 0.0}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:32:51.000Z',
  'batchId': 80,
  'numInputRows': 0,
  'inputRowsPerSecond': 0.0,
  'processedRowsPerSecond': 0.0,
  'durationMs': {'getOffset': 61, 'triggerExecution': 61},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 79},
    'endOffset': {'logOffset': 79},
    'numInputRows': 0,
    'inputRowsPerSecond': 0.0,
    'processedRowsPerSecond': 0.0}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:33:03.000Z',
  'batchId': 80,
  'numInputRows': 0,
  'inputRowsPerSecond': 0.0,
  'processedRowsPerSecond': 0.0,
  'durationMs': {'getOffset': 76, 'triggerExecution': 78},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 79},
    'endOffset': {'logOffset': 79},
    'numInputRows': 0,
    'inputRowsPerSecond': 0.0,
    'processedRowsPerSecond': 0.0}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:33:15.000Z',
  'batchId': 80,
  'numInputRows': 0,
  'inputRowsPerSecond': 0.0,
  'processedRowsPerSecond': 0.0,
  'durationMs': {'getOffset': 81, 'triggerExecution': 81},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 79},
    'endOffset': {'logOffset': 79},
    'numInputRows': 0,
    'inputRowsPerSecond': 0.0,
    'processedRowsPerSecond': 0.0}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:33:27.000Z',
  'batchId': 80,
  'numInputRows': 0,
  'inputRowsPerSecond': 0.0,
  'processedRowsPerSecond': 0.0,
  'durationMs': {'getOffset': 79, 'triggerExecution': 79},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 79},
    'endOffset': {'logOffset': 79},
    'numInputRows': 0,
    'inputRowsPerSecond': 0.0,
    'processedRowsPerSecond': 0.0}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:33:39.000Z',
  'batchId': 80,
  'numInputRows': 0,
  'inputRowsPerSecond': 0.0,
  'processedRowsPerSecond': 0.0,
  'durationMs': {'getOffset': 90, 'triggerExecution': 90},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 79},
    'endOffset': {'logOffset': 79},
    'numInputRows': 0,
    'inputRowsPerSecond': 0.0,
    'processedRowsPerSecond': 0.0}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:33:51.001Z',
  'batchId': 80,
  'numInputRows': 0,
  'inputRowsPerSecond': 0.0,
  'processedRowsPerSecond': 0.0,
  'durationMs': {'getOffset': 119, 'triggerExecution': 119},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 79},
    'endOffset': {'logOffset': 79},
    'numInputRows': 0,
    'inputRowsPerSecond': 0.0,
    'processedRowsPerSecond': 0.0}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}},
 {'id': 'e3afeaa6-9bcf-4181-93f9-61693d055b39',
  'runId': '4eca080d-ade2-40b7-9935-2149f3454993',
  'name': 'lesson02_ps',
  'timestamp': '2020-04-05T14:34:03.000Z',
  'batchId': 80,
  'numInputRows': 0,
  'inputRowsPerSecond': 0.0,
  'processedRowsPerSecond': 0.0,
  'durationMs': {'getOffset': 58, 'triggerExecution': 58},
  'stateOperators': [],
  'sources': [{'description': 'FileStreamSource[dbfs:/mnt/training/definitive-guide/data/activity-data-stream.json]',
    'startOffset': {'logOffset': 79},
    'endOffset': {'logOffset': 79},
    'numInputRows': 0,
    'inputRowsPerSecond': 0.0,
    'processedRowsPerSecond': 0.0}],
  'sink': {'description': 'FileSink[dbfs:/user/tbresee@mail.smu.edu/structured_streaming/ss_02___streaming_concepts_psp/output.parquet]'}}]
  """
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# ...

# %% [markdown]
# Additionally, we can iterate over a list of active streams:

# %%
for s in spark.streams.active:         # Iterate over all streams
  print("{}: {}".format(s.id, s.name)) # Print the stream's id and name
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">e3afeaa6-9bcf-4181-93f9-61693d055b39: lesson02_ps
# </div>

# %% [markdown]
# The code below introduces **`awaitTermination()`**
#
# **`awaitTermination()`** will block the current thread
# * Until the stream stops naturally or
# * Until the specified timeout elapses (if specified)
#
# If the stream was "canceled" or otherwise terminated abnormally, any resulting exceptions will be thrown by **`awaitTermination()`** as well.

# %%
try:
  
  # Stream for up to 10 seconds while the current thread blocks  
  streamingQuery.awaitTermination(10)  
  
except Exception as e:
  print(e)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Wait for it... And once the 10 seconds have elapsed without any error, we can explictly stop the stream.

# %%
try:
  
  # Issue the command to stop the stream
  streamingQuery.stop()

except Exception:
  print(e)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# -sandbox
# <img alt="Side Note" title="Side Note" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.05em; transform:rotate(15deg)" src="https://files.training.databricks.com/static/images/icon-note.webp"/> When working with streams, we are in reality, working with a separate "thread".
#
# As a result, different exceptions may arise as streams are terminated and/or queried.
#
# For this reason, we have developed a number of utility methods to help with these operations:
# * **`untilStreamIsReady(name)`** to wait until a stream is fully initialized before resuming execution.
# * **`stopAllStreams()`** to stop all active streams in a fail-safe manner.
#
# The implementation of each of these can be found in the notebook **`./Includes/Common-Notebooks/Utility-Methods`**

# %% [markdown]
# -sandbox
#
# <h2><img src="https://files.training.databricks.com/images/105/logo_spark_tiny.png"> The Display function</h2>
#
# Within the Databricks notebooks, we can use the `display()` function to render a live plot
#
# #### One Gotcha!
# When you pass a "streaming" `DataFrame` to `display`:
# * A "memory" sink is being used
# * The output mode is complete
# * The query name is specified with the `streamName` parameter
# * The trigger is specified with the `trigger` parameter
# * The checkpointing location is specified with the `checkpointLocation`
#
# `display(myDF, streamName = "myQuery")`
#
# <img alt="Side Note" title="Side Note" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.05em; transform:rotate(15deg)" src="https://files.training.databricks.com/static/images/icon-note.webp"/> We just programmatically stopped our only streaming query in the previous cell. In the cell below, `display` will automatically start our streaming DataFrame, `streamingDF`.  We are passing `stream_2p` as the name for this newly started stream.

# %%
display(streamingDF, streamName = myStreamName)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# Wait until stream is done initializing...
untilStreamIsReady(myStreamName)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The stream lesson02_ps is active and ready.
# </div>

# %% [markdown]
# Using the value passed to `streamName` in the call to `display`, we can programatically access this specific stream:

# %%
print("Looking for {}".format(myStreamName))

for stream in spark.streams.active:      # Loop over all active streams
  if stream.name == myStreamName:        # Single out "streamWithTimestamp"
    print("Found {} ({})".format(stream.name, stream.id))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Looking for lesson02_ps
# Found lesson02_ps (3da54a04-60a0-4b1b-a135-14e2b6fcb2f7)
# </div>

# %% [markdown]
# Stop all remaining streams.

# %%
stopAllStreams()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Stopping the stream lesson02_ps.
# The stream lesson02_ps was stopped.
# </div>

# %% [markdown]
# ## End-to-end Fault Tolerance
#
# Structured Streaming ensures end-to-end exactly-once fault-tolerance guarantees through _checkpointing_ and <a href="https://en.wikipedia.org/wiki/Write-ahead_logging" target="_blank">Write Ahead Logs</a>.
#
# Structured Streaming sources, sinks, and the underlying execution engine work together to track the progress of stream processing. If a failure occurs, the streaming engine attempts to restart and/or reprocess the data.
#
# This approach _only_ works if the streaming source is replayable. To ensure fault-tolerance, Structured Streaming assumes that every streaming source has offsets, akin to:
#
# * <a target="_blank" href="https://kafka.apache.org/documentation/#intro_topics">Kafka message offsets</a>
#
# At a high level, the underlying streaming mechanism relies on a couple approaches:
#
# * First, Structured Streaming uses checkpointing and write-ahead logs to record the offset range of data being processed during each trigger interval.
# * Next, the streaming sinks are designed to be _idempotent_—that is, multiple writes of the same data (as identified by the offset) do _not_ result in duplicates being written to the sink.
#
# Taken together, replayable data sources and idempotent sinks allow Structured Streaming to ensure **end-to-end, exactly-once semantics** under any failure condition.

# %% [markdown]
# <h2><img src="https://files.training.databricks.com/images/105/logo_spark_tiny.png"> Summary</h2>
#
# We use `readStream` to read streaming input from a variety of input sources and create a DataFrame.
#
# Nothing happens until we invoke `writeStream` or `display`.
#
# Using `writeStream` we can write to a variety of output sinks. Using `display` we draw LIVE bar graphs, charts and other plot types in the notebook.

# %% [markdown]
# <h2><img src="https://files.training.databricks.com/images/105/logo_spark_tiny.png"> Review Questions</h2>
#
# **Q:** What do `readStream` and `writeStream` do?<br>
# **A:** `readStream` creates a streaming DataFrame.<br>`writeStream` sends streaming data to a directory or other type of output sink.
#
# **Q:** What does `display` output if it is applied to a DataFrame created via `readStream`?<br>
# **A:** `display` sends streaming data to a LIVE graph!
#
# **Q:** When you do a write stream command, what does this option do `outputMode("append")` ?<br>
# **A:** This option takes on the following values and their respective meanings:
# * <b>append</b>: add only new records to output sink
# * <b>complete</b>: rewrite full output - applicable to aggregations operations
# * <b>update</b>: update changed records in place
#
# **Q:** What happens if you do not specify `option("checkpointLocation", pointer-to-checkpoint directory)`?<br>
# **A:** When the streaming job stops, you lose all state around your streaming job and upon restart, you start from scratch.
#
# **Q:** How do you view the list of active streams?<br>
# **A:** Invoke `spark.streams.active`.
#
# **Q:** How do you verify whether `streamingQuery` is running (boolean output)?<br>
# **A:** Invoke `spark.streams.get(streamingQuery.id).isActive`.

# %% [markdown]
# ## ![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) Classroom-Cleanup<br>
#
# Run the **`Classroom-Cleanup`** cell below to remove any artifacts created by this lesson.

# %%
# %run ./Includes/Classroom-Cleanup

# %% [markdown]
# <h2><img src="https://files.training.databricks.com/images/105/logo_spark_tiny.png"> Next Steps</h2>
#
# Start the next lab, [Streaming Concepts Lab]($./Labs/SS 02 - Streaming Concepts Lab).

# %% [markdown]
# <h2><img src="https://files.training.databricks.com/images/105/logo_spark_tiny.png"> Additional Topics &amp; Resources</h2>
# * <a href="https://spark.apache.org/docs/latest/structured-streaming-programming-guide.html#" target="_blank">Structured Streaming Programming Guide</a>
# * <a href="https://www.youtube.com/watch?v=rl8dIzTpxrI" target="_blank">A Deep Dive into Structured Streaming</a> by Tathagata Das. This is an excellent video describing how Structured Streaming works.

# %% [markdown]
# -sandbox
# &copy; 2020 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the <a href="http://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/>
# <a href="https://databricks.com/privacy-policy">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use">Terms of Use</a> | <a href="http://help.databricks.com/">Support</a>
